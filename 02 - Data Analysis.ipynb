# %% [markdown]
# # Data Analysis

# %% [markdown]
# Importing the required package:
#
# - [pandas](https://pandas.pydata.org/)
# - [requests](https://requests.readthedocs.io/en/master/)

# %%
import pandas
import requests

# %% [markdown]
# In the first example, we'll use the **WHOSIS_000001**, whose information can be seen by running the following code:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/Indicator?$filter=IndicatorCode eq 'WHOSIS_000001'")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator',
#  'value': [{'IndicatorCode': 'WHOSIS_000001',
#    'IndicatorName': 'Life expectancy at birth (years)',
#    'Language': 'EN'}]}

# %% [markdown]
# First, we'll get the all available data for the indicator:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/WHOSIS_000001")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': [{'Id': 15578241,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.0',
#    'NumericValue': 42.99474,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.203+02:00'},
#   {'Id': 15578243,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.4',
#    'NumericValue': 48.38779,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.36+02:00'},
#   {'Id': 15578245,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '45.7',
#    'NumericValue': 45.70058,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.453+02:00'},
#   {'Id': 15578247,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.5',
#    'NumericValue': 43.48892,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.58+02:00'},
#   {'Id': 15578249,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.5',
#    'NumericValue': 49.4939,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.687+02:00'},
#   {'Id': 15578251,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.5',
#    'NumericValue': 46.4939,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.777+02:00'},
#   {'Id': 15578253,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.0',
#    'NumericValue': 46.02686,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.83+02:00'},
#   {'Id': 15578255,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.5',
#    'NumericValue': 51.45327,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.893+02:00'},
#   {'Id': 15578257,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.8',
#    'NumericValue': 48.76327,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.943+02:00'},
#   {'Id': 15578259,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '47.4',
#    'NumericValue': 47.43979,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.07+02:00'},
#   {'Id': 15578261,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '52.9',
#    'NumericValue': 52.90927,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.127+02:00'},
#   {'Id': 15578263,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '50.2',
#    'NumericValue': 50.20816,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.193+02:00'},
#   {'Id': 15578265,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.0',
#    'NumericValue': 49.0172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.253+02:00'},
#   {'Id': 15578267,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.64111,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.31+02:00'},
#   {'Id': 15578269,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.9',
#    'NumericValue': 51.87408,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.4+02:00'},
#   {'Id': 15578271,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.0',
#    'NumericValue': 51.02977,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.523+02:00'},
#   {'Id': 15578273,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.1',
#    'NumericValue': 57.07021,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.58+02:00'},
#   {'Id': 15578275,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.1',
#    'NumericValue': 54.10822,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.63+02:00'},
#   {'Id': 15578277,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.3',
#    'NumericValue': 53.29705,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.697+02:00'},
#   {'Id': 15578279,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.0',
#    'NumericValue': 59.96988,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.777+02:00'},
#   {'Id': 15578281,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.7',
#    'NumericValue': 56.70158,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.853+02:00'},
#   {'Id': 15578283,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.2',
#    'NumericValue': 55.24638,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.937+02:00'},
#   {'Id': 15578285,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.2',
#    'NumericValue': 62.19933,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.997+02:00'},
#   {'Id': 15578287,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.8',
#    'NumericValue': 58.7995,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.05+02:00'},
#   {'Id': 15578289,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.4',
#    'NumericValue': 56.40147,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.107+02:00'},
#   {'Id': 15578291,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.3',
#    'NumericValue': 63.26159,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.213+02:00'},
#   {'Id': 15578293,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.91484,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.307+02:00'},
#   {'Id': 15578295,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.1',
#    'NumericValue': 56.06949,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.367+02:00'},
#   {'Id': 15578297,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.7',
#    'NumericValue': 63.65812,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.447+02:00'},
#   {'Id': 15578299,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.94343,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.513+02:00'},
#   {'Id': 15578301,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04501,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.58+02:00'},
#   {'Id': 15578303,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.9',
#    'NumericValue': 64.89055,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.68+02:00'},
#   {'Id': 15578305,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6',
#    'NumericValue': 61.56371,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.763+02:00'},
#   {'Id': 15578307,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90235,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.82+02:00'},
#   {'Id': 15578309,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.7',
#    'NumericValue': 65.69534,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.883+02:00'},
#   {'Id': 15578311,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.4',
#    'NumericValue': 62.39735,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.973+02:00'},
#   {'Id': 15578313,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.7',
#    'NumericValue': 59.65667,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.04+02:00'},
#   {'Id': 15578315,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.3',
#    'NumericValue': 66.2644,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.13+02:00'},
#   {'Id': 15578317,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.1',
#    'NumericValue': 63.06204,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.203+02:00'},
#   {'Id': 15578319,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.4',
#    'NumericValue': 60.40749,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.273+02:00'},
#   {'Id': 15578321,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.7',
#    'NumericValue': 66.72172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.343+02:00'},
#   {'Id': 15578323,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.7',
#    'NumericValue': 63.67279,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.453+02:00'},
#   {'Id': 15578325,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.1',
#    'NumericValue': 61.13641,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.823+02:00'},
#   {'Id': 15578327,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.1',
#    'NumericValue': 67.076,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.89+02:00'},
#   {'Id': 15578329,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.2',
#    'NumericValue': 64.22249,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.97+02:00'},
#   {'Id': 15578331,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.9',
#    'NumericValue': 61.87112,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.053+02:00'},
#   {'Id': 15578333,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.4',
#    'NumericValue': 67.39024,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.187+02:00'},
#   {'Id': 15578335,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.8',
#    'NumericValue': 64.75297,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.28+02:00'},
#   {'Id': 18156496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.60243,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.39+02:00'},
#   {'Id': 18156497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.3',
#    'NumericValue': 55.29549,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.423+02:00'},
#   {'Id': 18156498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.45111,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.443+02:00'},
#   {'Id': 18156499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.9',
#    'NumericValue': 56.94814,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.47+02:00'},
#   {'Id': 18156500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.36723,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.497+02:00'},
#   {'Id': 18156501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.8',
#    'NumericValue': 57.81836,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.52+02:00'},
#   {'Id': 18156502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04882,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.547+02:00'},
#   {'Id': 18156503,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.38523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.58+02:00'},
#   {'Id': 18156504,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.0',
#    'NumericValue': 59.0,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.61+02:00'},
#   {'Id': 18156505,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.5',
#    'NumericValue': 59.45721,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.63+02:00'},
#   {'Id': 18156506,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.90372,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.65+02:00'},
#   {'Id': 18156507,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.45234,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.673+02:00'},
#   {'Id': 18156508,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.9',
#    'NumericValue': 60.94415,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.7+02:00'},
#   {'Id': 18156509,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.5',
#    'NumericValue': 61.49583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.727+02:00'},
#   {'Id': 18156510,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.7',
#    'NumericValue': 61.65874,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.75+02:00'},
#   {'Id': 18156511,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.8',
#    'NumericValue': 61.79883,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.777+02:00'},
#   {'Id': 18156512,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 61.04462,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.807+02:00'},
#   {'Id': 18156514,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.3',
#    'NumericValue': 57.29959,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.853+02:00'},
#   {'Id': 18156515,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.9',
#    'NumericValue': 57.85725,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.877+02:00'},
#   {'Id': 18156516,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.5',
#    'NumericValue': 58.49403,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.893+02:00'},
#   {'Id': 18156517,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.1',
#    'NumericValue': 59.06556,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.913+02:00'},
#   {'Id': 18156518,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.6',
#    'NumericValue': 59.57045,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.937+02:00'},
#   {'Id': 18156519,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.1',
#    'NumericValue': 60.08017,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.96+02:00'},
#   {'Id': 18156520,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.5066,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.987+02:00'},
#   {'Id': 18156521,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 60.97018,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.01+02:00'},
#   {'Id': 18156522,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6',
#    'NumericValue': 61.56165,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.033+02:00'},
#   {'Id': 18156523,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.1',
#    'NumericValue': 62.06646,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.053+02:00'},
#   {'Id': 18156524,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.5',
#    'NumericValue': 62.54279,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.08+02:00'},
#   {'Id': 18156525,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.1',
#    'NumericValue': 63.07744,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.103+02:00'},
#   {'Id': 18156526,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.6',
#    'NumericValue': 63.55457,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.123+02:00'},
#   {'Id': 18156527,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.1',
#    'NumericValue': 64.07648,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.143+02:00'},
#   {'Id': 18156528,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.4',
#    'NumericValue': 64.37848,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.163+02:00'},
#   {'Id': 18156529,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.7',
#    'NumericValue': 64.67819,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.187+02:00'},
#   {'Id': 18156530,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.5',
#    'NumericValue': 64.49557,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.207+02:00'},
#   {'Id': 18156532,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.9',
#    'NumericValue': 55.89618,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.25+02:00'},
#   {'Id': 18156533,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.52523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.27+02:00'},
#   {'Id': 18156534,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.43997,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.29+02:00'},
#   {'Id': 18156535,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 57.971,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.31+02:00'},
#   {'Id': 18156536,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.42978,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.333+02:00'},
#   {'Id': 18156537,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90924,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.353+02:00'},
#   {'Id': 18156538,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.2',
#    'NumericValue': 59.23066,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.37+02:00'},
#   {'Id': 18156539,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.6',
#    'NumericValue': 59.62808,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.39+02:00'},
#   {'Id': 18156540,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.2',
#    'NumericValue': 60.23545,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.42+02:00'},
#   {'Id': 18156541,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
# ...
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.0',
#    'NumericValue': 72.02805,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.91+02:00'},
#   {'Id': 18157472,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.4',
#    'NumericValue': 72.38357,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.93+02:00'},
#   {'Id': 18157473,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.6',
#    'NumericValue': 71.61191,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.957+02:00'},
#   {'Id': 18157474,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.5',
#    'NumericValue': 72.52351,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.977+02:00'},
#   {'Id': 18157475,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3',
#    'NumericValue': 72.33039,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56+02:00'},
#   {'Id': 18157476,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.0',
#    'NumericValue': 72.95933,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.02+02:00'},
#   {'Id': 18157477,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.3',
#    'NumericValue': 73.25368,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.04+02:00'},
#   {'Id': 18157478,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.5',
#    'NumericValue': 73.49396,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.06+02:00'},
#   {'Id': 18157479,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9',
#    'NumericValue': 73.93802,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.08+02:00'},
#   {'Id': 18157480,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.0',
#    'NumericValue': 74.03307,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.103+02:00'},
#   {'Id': 18157481,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.11275,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.127+02:00'},
#   {'Id': 18157482,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.13898,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.15+02:00'},
#   {'Id': 18157483,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.5',
#    'NumericValue': 74.52892,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.173+02:00'},
#   {'Id': 18157484,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.8',
#    'NumericValue': 74.75126,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.193+02:00'},
#   {'Id': 18157486,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.1',
#    'NumericValue': 77.09014,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.233+02:00'},
#   {'Id': 18157487,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.69583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.257+02:00'},
#   {'Id': 18157488,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.8',
#    'NumericValue': 77.78509,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.277+02:00'},
#   {'Id': 18157489,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.6',
#    'NumericValue': 77.57087,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.303+02:00'},
#   {'Id': 18157490,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.5',
#    'NumericValue': 77.54809,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.323+02:00'},
#   {'Id': 18157491,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.3',
#    'NumericValue': 77.28371,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.347+02:00'},
#   {'Id': 18157492,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9',
#    'NumericValue': 77.91827,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.367+02:00'},
#   {'Id': 18157493,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.72093,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.39+02:00'},
#   {'Id': 18157494,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.5',
#    'NumericValue': 78.5369,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.437+02:00'},
#   {'Id': 18157495,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.4',
#    'NumericValue': 78.40302,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.473+02:00'},
#   {'Id': 18157496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6',
#    'NumericValue': 78.5621,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.5+02:00'},
#   {'Id': 18157497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.1',
#    'NumericValue': 79.13873,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.52+02:00'},
#   {'Id': 18157498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.2',
#    'NumericValue': 79.24512,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.55+02:00'},
#   {'Id': 18157499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3',
#    'NumericValue': 79.29684,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.57+02:00'},
#   {'Id': 18157500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3',
#    'NumericValue': 79.32494,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.59+02:00'},
#   {'Id': 18157501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.6',
#    'NumericValue': 79.57848,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.617+02:00'},
#   {'Id': 18157502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.8',
#    'NumericValue': 79.75803,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.64+02:00'},
#   ...]}

# %% [markdown]
# and extract the list of records for later use:

# %%
records = response.json()['value']

# %% [markdown]
# We use the [pandas.DataFrom.from_records()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_records.html) method to create a DataFrame from the records

# %%
df = pandas.DataFrame.from_records(records)
df
# Out:
#             Id  IndicatorCode SpatialDimType SpatialDim TimeDimType  TimeDim  \
# 0     15578241  WHOSIS_000001        COUNTRY        RWA        YEAR     2000
# 1     15578243  WHOSIS_000001        COUNTRY        RWA        YEAR     2000
# 2     15578245  WHOSIS_000001        COUNTRY        RWA        YEAR     2000
# 3     15578247  WHOSIS_000001        COUNTRY        RWA        YEAR     2001
# 4     15578249  WHOSIS_000001        COUNTRY        RWA        YEAR     2001
# ...        ...            ...            ...        ...         ...      ...
# 9481  18181850  WHOSIS_000001         REGION        WPR        YEAR     2000
# 9482  18181851  WHOSIS_000001         REGION        WPR        YEAR     2005
# 9483  18181852  WHOSIS_000001         REGION        WPR        YEAR     2010
# 9484  18181853  WHOSIS_000001         REGION        WPR        YEAR     2015
# 9485  18181854  WHOSIS_000001         REGION        WPR        YEAR     2016
#
#      Dim1Type  Dim1 Dim2Type  Dim2 Dim3Type  Dim3 DataSourceDimType  \
# 0         SEX   MLE     None  None     None  None              None
# 1         SEX  FMLE     None  None     None  None              None
# 2         SEX  BTSX     None  None     None  None              None
# 3         SEX   MLE     None  None     None  None              None
# 4         SEX  FMLE     None  None     None  None              None
# ...       ...   ...      ...   ...      ...   ...               ...
# 9481      SEX  BTSX     None  None     None  None              None
# 9482      SEX  BTSX     None  None     None  None              None
# 9483      SEX  BTSX     None  None     None  None              None
# 9484      SEX  BTSX     None  None     None  None              None
# 9485      SEX  BTSX     None  None     None  None              None
#
#      DataSourceDim Value  NumericValue   Low  High Comments  \
# 0             None  43.0      42.99474  None  None     None
# 1             None  48.4      48.38779  None  None     None
# 2             None  45.7      45.70058  None  None     None
# 3             None  43.5      43.48892  None  None     None
# 4             None  49.5      49.49390  None  None     None
# ...            ...   ...           ...   ...   ...      ...
# 9481          None  72.8      72.80718  None  None     None
# 9482          None  74.7      74.68253  None  None     None
# 9483          None  75.8      75.77744  None  None     None
# 9484          None  76.7      76.70511  None  None     None
# 9485          None  76.9      76.89359  None  None     None
#
#                                Date
# 0     2017-03-31T08:14:36.203+02:00
# 1      2017-03-31T08:14:36.36+02:00
# 2     2017-03-31T08:14:36.453+02:00
# 3      2017-03-31T08:14:36.58+02:00
# 4     2017-03-31T08:14:36.687+02:00
# ...                             ...
# 9481    2018-04-06T10:50:13.8+02:00
# 9482   2018-04-06T10:50:13.82+02:00
# 9483   2018-04-06T10:50:13.84+02:00
# 9484  2018-04-06T10:50:13.857+02:00
# 9485  2018-04-06T10:50:13.877+02:00
#
# [9486 rows x 20 columns]

# %% [markdown]
# We can use the [.info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) method get get some basic information about the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9486 entries, 0 to 9485
# Data columns (total 20 columns):
# Id                   9486 non-null int64
# IndicatorCode        9486 non-null object
# SpatialDimType       9486 non-null object
# SpatialDim           9486 non-null object
# TimeDimType          9486 non-null object
# TimeDim              9486 non-null int64
# Dim1Type             9486 non-null object
# Dim1                 9486 non-null object
# Dim2Type             0 non-null object
# Dim2                 0 non-null object
# Dim3Type             0 non-null object
# Dim3                 0 non-null object
# DataSourceDimType    0 non-null object
# DataSourceDim        0 non-null object
# Value                9486 non-null object
# NumericValue         9486 non-null float64
# Low                  0 non-null object
# High                 0 non-null object
# Comments             9333 non-null object
# Date                 9486 non-null object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.4+ MB

# %% [markdown]
# as well as its [.shape](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html):

# %%
df.shape
# Out:
# (9486, 20)

# %% [markdown]
# We'll make sure to remove any duplicates by running [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (9486, 20)

# %% [markdown]
# Let's calculate to total number of nulls in each column of our dataset.
#
# The first step is to check which cells in our DataFrame are null:

# %%
df.isnull()
# Out:
#          Id  IndicatorCode  SpatialDimType  SpatialDim  TimeDimType  TimeDim  \
# 0     False          False           False       False        False    False
# 1     False          False           False       False        False    False
# 2     False          False           False       False        False    False
# 3     False          False           False       False        False    False
# 4     False          False           False       False        False    False
# ...     ...            ...             ...         ...          ...      ...
# 9481  False          False           False       False        False    False
# 9482  False          False           False       False        False    False
# 9483  False          False           False       False        False    False
# 9484  False          False           False       False        False    False
# 9485  False          False           False       False        False    False
#
#       Dim1Type   Dim1  Dim2Type  Dim2  Dim3Type  Dim3  DataSourceDimType  \
# 0        False  False      True  True      True  True               True
# 1        False  False      True  True      True  True               True
# 2        False  False      True  True      True  True               True
# 3        False  False      True  True      True  True               True
# 4        False  False      True  True      True  True               True
# ...        ...    ...       ...   ...       ...   ...                ...
# 9481     False  False      True  True      True  True               True
# 9482     False  False      True  True      True  True               True
# 9483     False  False      True  True      True  True               True
# 9484     False  False      True  True      True  True               True
# 9485     False  False      True  True      True  True               True
#
#       DataSourceDim  Value  NumericValue   Low  High  Comments   Date
# 0              True  False         False  True  True      True  False
# 1              True  False         False  True  True      True  False
# 2              True  False         False  True  True      True  False
# 3              True  False         False  True  True      True  False
# 4              True  False         False  True  True      True  False
# ...             ...    ...           ...   ...   ...       ...    ...
# 9481           True  False         False  True  True      True  False
# 9482           True  False         False  True  True      True  False
# 9483           True  False         False  True  True      True  False
# 9484           True  False         False  True  True      True  False
# 9485           True  False         False  True  True      True  False
#
# [9486 rows x 20 columns]

# %% [markdown]
# To count the number of nulls in each column we use an aggregate function for summing:

# %%
df.isnull().sum()
# Out:
# Id                      0
# IndicatorCode           0
# SpatialDimType          0
# SpatialDim              0
# TimeDimType             0
# TimeDim                 0
# Dim1Type                0
# Dim1                    0
# Dim2Type             9486
# Dim2                 9486
# Dim3Type             9486
# Dim3                 9486
# DataSourceDimType    9486
# DataSourceDim        9486
# Value                   0
# NumericValue            0
# Low                  9486
# High                 9486
# Comments              153
# Date                    0
# dtype: int64

# %% [markdown]
# We'll drop the columns with null values by using `dropna()` and setting `axis=1`:

# %%
df.dropna(axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9486 entries, 0 to 9485
# Data columns (total 11 columns):
# Id                9486 non-null int64
# IndicatorCode     9486 non-null object
# SpatialDimType    9486 non-null object
# SpatialDim        9486 non-null object
# TimeDimType       9486 non-null object
# TimeDim           9486 non-null int64
# Dim1Type          9486 non-null object
# Dim1              9486 non-null object
# Value             9486 non-null object
# NumericValue      9486 non-null float64
# Date              9486 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 889.3+ KB

# %% [markdown]
# Rename the columns to be used:

# %%
df.rename(columns={
    'Id': 'id', 
    'IndicatorCode': 'code',
    'SpatialDimType': 'spatial_dimension_type',
    'SpatialDim': 'spatial_dimension',
    'TimeDimType': 'time_dimension_type',
    'TimeDim': 'time_dimension',
    'Dim1Type': 'extra_dimension_type',
    'Dim1': 'extra_dimension',
    'Value': 'value',
    'NumericValue': 'value_numeric',
    'Comments': 'comments',
    'Date': 'date',
}, inplace=True)
df.columns
# Out:
# Index(['id', 'code', 'spatial_dimension_type', 'spatial_dimension',
#        'time_dimension_type', 'time_dimension', 'extra_dimension_type',
#        'extra_dimension', 'value', 'value_numeric', 'date'],
#       dtype='object')

# %% [markdown]
# Using `describe()` on an entire DataFrame we can get a summary of the distribution of continuous variables:

# %%
df.describe()
# Out:
#                  id  time_dimension  value_numeric
# count  9.486000e+03     9486.000000    9486.000000
# mean   1.814859e+07     2008.010753      69.101396
# std    1.833449e+05        4.913730       9.382723
# min    1.557824e+07     2000.000000      33.227470
# 25%    1.815896e+07     2004.000000      62.784467
# 50%    1.816147e+07     2008.000000      71.060850
# 75%    1.816398e+07     2012.000000      76.213930
# max    1.818185e+07     2016.000000      87.145020

# %% [markdown]
# `.describe()` can also be used on a categorical variable to get the count of rows, unique count of categories, top category, and freq of top category:

# %%
df['spatial_dimension'].describe()
# Out:
# count     9486
# unique     190
# top        RWA
# freq        99
# Name: spatial_dimension, dtype: object

# %%
df['extra_dimension'].describe()
# Out:
# count     9486
# unique       3
# top       FMLE
# freq      3162
# Name: extra_dimension, dtype: object

# %% [markdown]
# `.value_counts()` can tell us the frequency of all values in a column:

# %%
df['spatial_dimension'].value_counts().head(10)
# Out:
# RWA    99
# BWA    51
# COG    51
# SLE    51
# CMR    51
# FRA    51
# URY    51
# OMN    51
# STP    51
# LVA    51
# Name: spatial_dimension, dtype: int64

# %% [markdown]
# By using the correlation method `.corr()` we can generate the relationship between each continuous variable:

# %%
df.corr()
# Out:
#                       id  time_dimension  value_numeric
# id              1.000000        0.007736       0.090730
# time_dimension  0.007736        1.000000       0.188926
# value_numeric   0.090730        0.188926       1.000000

# %% [markdown]
# Positive numbers indicate a positive correlation — one goes up the other goes up — and negative numbers represent an inverse correlation — one goes up the other goes down. 1.0 indicates a perfect correlation.

# %% [markdown]
# We can see here that the highest correlation is time/ value with ~0.2, not very strong...

# %% [markdown]
# To index the first record of the set, we simply do:

# %%
record = df.loc[1]
record
# Out:
# id                                             15578245
# code                                      WHOSIS_000001
# spatial_dimension_type                          COUNTRY
# spatial_dimension                                   RWA
# time_dimension_type                                YEAR
# time_dimension                                     2000
# extra_dimension_type                                SEX
# extra_dimension                                    BTSX
# value                                              45.7
# value_numeric                                   45.7006
# date                      2017-03-31T08:14:36.453+02:00
# Name: 2, dtype: object
