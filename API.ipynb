# %% [markdown]
# # API

# %% [markdown]
#  > **NOTE:** More information on WHO APIs used in this notebook can be found here: https://www.who.int/data/gho/info/gho-odata-api

# %% [markdown]
# ## Retrieving the list of available dimensions

# %% [markdown]
# The [api/Dimension](https://ghoapi.azureedge.net/api/Dimension) URL will give you a list of **Dimensions**, which are of type **(Code, Title)**:

# %%
import requests

# %%
response = requests.get("https://ghoapi.azureedge.net/api/Dimension")

# %%
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#DIMENSION',
#  'value': [{'Code': 'ADVERTISINGTYPE',
#    'Title': 'SUBSTANCE_ABUSE_ADVERTISING_TYPES'},
#   {'Code': 'AGEGROUP', 'Title': 'Age Group'},
#   {'Code': 'ALCOHOLTYPE', 'Title': 'Beverage Types'},
#   {'Code': 'AMRGLASSCATEGORY', 'Title': 'AMR GLASS Category'},
#   {'Code': 'AWARENESSACTIVITYTYPE',
#    'Title': 'SUBSTANCE_ABUSE_AWARENESS_ACTIVITY_TYPES'},
#   {'Code': 'BACGROUP', 'Title': 'SUBSTANCE_ABUSE_BAC_GROUPS'},
#   {'Code': 'BEVERAGETYPE', 'Title': 'SUBSTANCE_ABUSE_BEVERAGE_TYPES'},
#   {'Code': 'CHILDCAUSE', 'Title': 'Cause of death'},
#   {'Code': 'COMMUNITYACTIONTYPE', 'Title': 'Community Action'},
#   {'Code': 'CONSUMPTIONTYPE', 'Title': 'Consumption type'},
#   {'Code': 'COORDINATINGENTITIES',
#    'Title': 'SUBSTANCE_ABUSE_COORDINATING_ENTITIES'},
#   {'Code': 'COUNTRY', 'Title': 'Country'},
#   {'Code': 'DATASOURCE', 'Title': 'Data Source'},
#   {'Code': 'DHSMICSGEOREGION', 'Title': 'Subnational region'},
#   {'Code': 'DRIVERTYPE', 'Title': 'Driver Type'},
#   {'Code': 'DRUG', 'Title': 'RSUD_DRUGS'},
#   {'Code': 'DRUGPRESCRIPTION', 'Title': 'RSUD_DRUG_PRESCRIPTION'},
#   {'Code': 'DRUGSUPERVISION', 'Title': 'RSUD_DRUG_SUPERVISION'},
#   {'Code': 'EDUCATIONLEVEL', 'Title': 'Education Level'},
#   {'Code': 'EMFBODYPART', 'Title': 'Body part'},
#   {'Code': 'EMFEXPOSED', 'Title': 'Exposed'},
#   {'Code': 'EMFFREQUENCY', 'Title': 'Frequency'},
#   {'Code': 'EMFRADIOBAND', 'Title': 'Radio band'},
#   {'Code': 'ENVCAUSE', 'Title': 'Cause'},
#   {'Code': 'GBDREGION', 'Title': 'GBD Region'},
#   {'Code': 'GHECAUSES', 'Title': 'Causes'},
#   {'Code': 'GHO', 'Title': 'Indicator'},
#   {'Code': 'GOEQUESTION', 'Title': 'Goe question'},
#   {'Code': 'GOVERNMENTBENEFIT', 'Title': 'RSUD_GOVERNMENT_BENEFITS'},
#   {'Code': 'GROUP', 'Title': 'RSUD_GROUPS'},
#   {'Code': 'HARMANDCONSEQUENCE',
#    'Title': 'SUBSTANCE_ABUSE_HARM_AND_CONSEQUENCES'},
#   {'Code': 'IHRSPARCAPACITYLEVEL', 'Title': 'IHR SPAR Capacity Level'},
#   {'Code': 'INADEQUACY', 'Title': 'Inadequacy'},
#   {'Code': 'KE_CORE', 'Title': 'Kenya Core Indicators'},
#   {'Code': 'KE_COUNTY', 'Title': 'County'},
#   {'Code': 'LEGISLATIONTYPE', 'Title': 'Legislation type'},
#   {'Code': 'MEASUREIMPORTANCETYPE',
#    'Title': 'SUBSTANCE_ABUSE_MEASURE_IMPORTANCE_TYPE'},
#   {'Code': 'MGHEREG', 'Title': 'Region'},
#   {'Code': 'MOTOCYCLEOCCUPANTTYPE', 'Title': 'Motorcycle Occupant Type'},
#   {'Code': 'NATIONALSYSTEMTYPE', 'Title': 'National System Type'},
#   {'Code': 'NGO', 'Title': 'RSUD_NGOS'},
#   {'Code': 'OPENACCESSSERVICE', 'Title': 'RSUD_OPEN_ACCESS_SERVICES'},
#   {'Code': 'PENALTYTYPE', 'Title': 'Penalty Type'},
#   {'Code': 'POLICYADOPTIONLEVEL',
#    'Title': 'SUBSTANCE_ABUSE_POLICY_ADOPTION_LEVELS'},
#   {'Code': 'POLICYFRAMEWORK', 'Title': 'SUBSTANCE_ABUSE_POLICY_FRAMEWORKS'},
#   {'Code': 'PRICEMEASURETYPE', 'Title': 'Price measure types'},
#   {'Code': 'PROGRAMME', 'Title': 'RSUD_PROGRAMMES'},
#   {'Code': 'PUBLICPLACE', 'Title': 'SUBSTANCE_ABUSE_PUBLIC_PLACES'},
#   {'Code': 'PUBLICPRIVATESETTING', 'Title': 'RSUD_PUBLIC_PRIVATE_SETTINGS'},
#   {'Code': 'PUBLISHSTATE', 'Title': 'PUBLISH STATES'},
#   {'Code': 'REGION', 'Title': 'WHO region'},
#   {'Code': 'RESIDENCEAREATYPE', 'Title': 'Residence Area Type'},
#   {'Code': 'ROADUSERTYPE', 'Title': 'Road User Type'},
#   {'Code': 'RSUD_HIVHEP_CT',
#    'Title': 'HIV / Hepatitis counselling and treatment'},
#   {'Code': 'RSUDHWF', 'Title': 'Human resources / health workforce'},
#   {'Code': 'RSUDMAINSUBSTANCEATTREATMENT',
#    'Title': 'RSUD Main substance at treatment'},
#   {'Code': 'RSUDMAINTENANCEACCESSRESTRICTIONS',
#    'Title': 'Maintenance access restrictions'},
#   {'Code': 'RSUDMONITORING', 'Title': 'Monitoring system'},
#   {'Code': 'RSUDPHARMACOTHERAPYOPTION', 'Title': 'Pharmacotherapy options'},
#   {'Code': 'RSUDPREVENTIONPROGRAMME', 'Title': 'Prevention programmes'},
#   {'Code': 'RSUDREP', 'Title': 'Representatives'},
#   {'Code': 'RSUDREPORTING', 'Title': 'Sources of reporting'},
#   {'Code': 'RSUDSPECIFICPOPULATION', 'Title': 'Specific populations'},
#   {'Code': 'RSUDSUBSTANCEDEPENDENCE', 'Title': 'Substance dependence'},
#   {'Code': 'RSUDTREATMENT', 'Title': 'Treatment'},
#   {'Code': 'RSUDTREATMENTLOCATION', 'Title': 'Treatment location'},
#   {'Code': 'SEATTYPE', 'Title': 'Seat Type'},
#   {'Code': 'SEX', 'Title': 'Sex'},
#   {'Code': 'SOCIALCOSTTYPE', 'Title': 'SUBSTANCE_ABUSE_SOCIAL_COST_TYPES'},
#   {'Code': 'SPONSORSHIPORIGINATOR', 'Title': 'Sponsorship originator'},
#   {'Code': 'STANDARDOFCARE', 'Title': 'RSUD_STANDARDS_OF_CARE'},
#   {'Code': 'SUBSTANCETYPE', 'Title': 'RSUD_SUBSTANCE_TYPES'},
#   {'Code': 'SUBSTANCETYPEDISORDER', 'Title': 'RSUD_SUBSTANCE_TYPE_DISORDERS'},
#   {'Code': 'SUNBED_ACCESS', 'Title': 'Sunbed access restrictions'},
#   {'Code': 'SUNBED_CONTROL',
#    'Title': 'Restriction and inspection of sunbed facilities'},
#   {'Code': 'SUNBED_INFO', 'Title': 'Sunbed public information requirements'},
#   {'Code': 'SUNBED_SAFETY', 'Title': 'Sunbed facility safety requirements'},
#   {'Code': 'SUNBED_TRAINING',
#    'Title': 'Sunbed facility staff training requirements'},
#   {'Code': 'UNREGION', 'Title': 'UN Region'},
#   {'Code': 'UNSDGREGION', 'Title': 'UN SDG Region'},
#   {'Code': 'VEHICLESTANDARD', 'Title': 'Vehicle standards'},
#   {'Code': 'WEALTHQUINTILE', 'Title': 'Wealth Quintile'},
#   {'Code': 'WHOINCOMEREGION', 'Title': 'WHO Income Region'},
#   {'Code': 'WORLDBANKINCOMEGROUP', 'Title': 'World Bank income group'},
#   {'Code': 'WORLDBANKREGION', 'Title': 'World Bank Region'},
#   {'Code': 'YEAR', 'Title': 'Year'}]}

# %% [markdown]
# ## Retrieving a list of available values for a specific dimension

# %% [markdown]
# You can use the **Codes** of the **Dimensions** from the [api/Dimension](https://ghoapi.azureedge.net/api/Dimension) API to get the values for that **Dimension**, by using the [api/DIMENSION/*CODE*/DimensionValues](https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues) API (This example uses the **COUNTRY** code as an example):

# %%
response = requests.get("https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Collection(Default.DIMENSION_VALUE)',
#  'value': [{'Code': 'AGO',
#    'Title': 'Angola',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'BDI',
#    'Title': 'Burundi',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'BEN',
#    'Title': 'Benin',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'BFA',
#    'Title': 'Burkina Faso',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'BWA',
#    'Title': 'Botswana',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'CAF',
#    'Title': 'Central African Republic',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'TZA',
#    'Title': 'United Republic of Tanzania',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'UGA',
#    'Title': 'Uganda',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'ZAF',
#    'Title': 'South Africa',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'ZMB',
#    'Title': 'Zambia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'ZWE',
#    'Title': 'Zimbabwe',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'SSD',
#    'Title': 'South Sudan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'STP',
#    'Title': 'Sao Tome and Principe',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'SWZ',
#    'Title': 'Eswatini',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'SYC',
#    'Title': 'Seychelles',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'TCD',
#    'Title': 'Chad',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'TGO',
#    'Title': 'Togo',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'NAM',
#    'Title': 'Namibia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'NER',
#    'Title': 'Niger',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'NGA',
#    'Title': 'Nigeria',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'RWA',
#    'Title': 'Rwanda',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'SEN',
#    'Title': 'Senegal',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'SLE',
#    'Title': 'Sierra Leone',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'MDG',
#    'Title': 'Madagascar',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'MLI',
#    'Title': 'Mali',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'MOZ',
#    'Title': 'Mozambique',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'MRT',
#    'Title': 'Mauritania',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'MUS',
#    'Title': 'Mauritius',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'MWI',
#    'Title': 'Malawi',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'GMB',
#    'Title': 'Gambia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'GNB',
#    'Title': 'Guinea-Bissau',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'GNQ',
#    'Title': 'Equatorial Guinea',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'KEN',
#    'Title': 'Kenya',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'LBR',
#    'Title': 'Liberia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'LSO',
#    'Title': 'Lesotho',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'DZA',
#    'Title': 'Algeria',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'ERI',
#    'Title': 'Eritrea',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'ETH',
#    'Title': 'Ethiopia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'GAB',
#    'Title': 'Gabon',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'GHA',
#    'Title': 'Ghana',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'GIN',
#    'Title': 'Guinea',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'CIV',
#    'Title': "Côte d'Ivoire",
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'CMR',
#    'Title': 'Cameroon',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'COD',
#    'Title': 'Democratic Republic of the Congo',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'COG',
#    'Title': 'Congo',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'COM',
#    'Title': 'Comoros',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'CPV',
#    'Title': 'Cabo Verde',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AFR',
#    'ParentTitle': 'Africa'},
#   {'Code': 'ANT530',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'ANT532',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'ARG',
#    'Title': 'Argentina',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'ATG',
#    'Title': 'Antigua and Barbuda',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'BHS',
#    'Title': 'Bahamas',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'BLZ',
#    'Title': 'Belize',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'USA',
#    'Title': 'United States of America',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'VCT',
#    'Title': 'Saint Vincent and the Grenadines',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'VEN',
#    'Title': 'Venezuela (Bolivarian Republic of)',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'PRI',
#    'Title': 'Puerto Rico',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'PRY',
#    'Title': 'Paraguay',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'SLV',
#    'Title': 'El Salvador',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'SUR',
#    'Title': 'Suriname',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'TTO',
#    'Title': 'Trinidad and Tobago',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'URY',
#    'Title': 'Uruguay',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'KNA',
#    'Title': 'Saint Kitts and Nevis',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'LCA',
#    'Title': 'Saint Lucia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'MEX',
#    'Title': 'Mexico',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'NIC',
#    'Title': 'Nicaragua',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'PAN',
#    'Title': 'Panama',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'PER',
#    'Title': 'Peru',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'GRD',
#    'Title': 'Grenada',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'GTM',
#    'Title': 'Guatemala',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'GUY',
#    'Title': 'Guyana',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'HND',
#    'Title': 'Honduras',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'HTI',
#    'Title': 'Haiti',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'JAM',
#    'Title': 'Jamaica',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'CRI',
#    'Title': 'Costa Rica',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'CUB',
#    'Title': 'Cuba',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'DMA',
#    'Title': 'Dominica',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'DOM',
#    'Title': 'Dominican Republic',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'ECU',
#    'Title': 'Ecuador',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'GLP312',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'BOL',
#    'Title': 'Bolivia (Plurinational State of)',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'BRA',
#    'Title': 'Brazil',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'BRB',
#    'Title': 'Barbados',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'CAN',
#    'Title': 'Canada',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'CHL',
#    'Title': 'Chile',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'COL',
#    'Title': 'Colombia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'AMR',
#    'ParentTitle': 'Americas'},
#   {'Code': 'AFG',
#    'Title': 'Afghanistan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'ARE',
#    'Title': 'United Arab Emirates',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'BHR',
#    'Title': 'Bahrain',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'DJI',
#    'Title': 'Djibouti',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'EGY',
#    'Title': 'Egypt',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'IRN',
#    'Title': 'Iran (Islamic Republic of)',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'SDN736',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'SOM',
#    'Title': 'Somalia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'SYR',
#    'Title': 'Syrian Arab Republic',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'TUN',
#    'Title': 'Tunisia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'YEM',
#    'Title': 'Yemen',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'YEM886',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'OMN',
#    'Title': 'Oman',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'PAK',
#    'Title': 'Pakistan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'PSE',
#    'Title': 'West Bank and Gaza Strip',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'QAT',
#    'Title': 'Qatar',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'SAU',
#    'Title': 'Saudi Arabia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'SDN',
#    'Title': 'Sudan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'IRQ',
#    'Title': 'Iraq',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'JOR',
#    'Title': 'Jordan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'KWT',
#    'Title': 'Kuwait',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'LBN',
#    'Title': 'Lebanon',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'LBY',
#    'Title': 'Libya',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'MAR',
#    'Title': 'Morocco',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EMR',
#    'ParentTitle': 'Eastern Mediterranean'},
#   {'Code': 'ALB',
#    'Title': 'Albania',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'AND',
#    'Title': 'Andorra',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'ARM',
#    'Title': 'Armenia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'AUT',
#    'Title': 'Austria',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'AZE',
#    'Title': 'Azerbaijan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'BEL',
#    'Title': 'Belgium',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'YUG890',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'YUG891',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SWE',
#    'Title': 'Sweden',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'TJK',
#    'Title': 'Tajikistan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'TKM',
#    'Title': 'Turkmenistan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'TUR',
#    'Title': 'Turkey',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'UKR',
#    'Title': 'Ukraine',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'UZB',
#    'Title': 'Uzbekistan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SCG891',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SMR',
#    'Title': 'San Marino',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SRB',
#    'Title': 'Serbia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SUN810',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SVK',
#    'Title': 'Slovakia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'SVN',
#    'Title': 'Slovenia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'NLD',
#    'Title': 'Netherlands',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'NOR',
#    'Title': 'Norway',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'POL',
#    'Title': 'Poland',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'PRT',
#    'Title': 'Portugal',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'ROU',
#    'Title': 'Romania',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'RUS',
#    'Title': 'Russian Federation',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'LVA',
#    'Title': 'Latvia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'MCO',
#    'Title': 'Monaco',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'MDA',
#    'Title': 'Republic of Moldova',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'MKD',
#    'Title': 'Republic of North Macedonia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'MLT',
#    'Title': 'Malta',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'MNE',
#    'Title': 'Montenegro',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'ITA',
#    'Title': 'Italy',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'KAZ',
#    'Title': 'Kazakhstan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'KGZ',
#    'Title': 'Kyrgyzstan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'LIE',
#    'Title': 'Liechtenstein',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'LTU',
#    'Title': 'Lithuania',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'LUX',
#    'Title': 'Luxembourg',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'GRC',
#    'Title': 'Greece',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'HRV',
#    'Title': 'Croatia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'HUN',
#    'Title': 'Hungary',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'IRL',
#    'Title': 'Ireland',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'ISL',
#    'Title': 'Iceland',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'ISR',
#    'Title': 'Israel',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'ESP',
#    'Title': 'Spain',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'EST',
#    'Title': 'Estonia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'FIN',
#    'Title': 'Finland',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'FRA',
#    'Title': 'France',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'GBR',
#    'Title': 'United Kingdom of Great Britain and Northern Ireland',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'GEO',
#    'Title': 'Georgia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'CZE',
#    'Title': 'Czechia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'DDR278',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'DEU',
#    'Title': 'Germany',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'DEU280',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'DEU284',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'DNK',
#    'Title': 'Denmark',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'BGR',
#    'Title': 'Bulgaria',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'BIH',
#    'Title': 'Bosnia and Herzegovina',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'BLR',
#    'Title': 'Belarus',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'CHE',
#    'Title': 'Switzerland',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'CSK200',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'CYP',
#    'Title': 'Cyprus',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'EUR',
#    'ParentTitle': 'Europe'},
#   {'Code': 'BGD',
#    'Title': 'Bangladesh',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'BTN',
#    'Title': 'Bhutan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'IDN',
#    'Title': 'Indonesia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'IND',
#    'Title': 'India',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'IND975',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'LKA',
#    'Title': 'Sri Lanka',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'MDV',
#    'Title': 'Maldives',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'MMR',
#    'Title': 'Myanmar',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'NPL',
#    'Title': 'Nepal',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'PRK',
#    'Title': "Democratic People's Republic of Korea",
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'THA',
#    'Title': 'Thailand',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'TLS',
#    'Title': 'Timor-Leste',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'SEAR',
#    'ParentTitle': 'South-East Asia'},
#   {'Code': 'AUS',
#    'Title': 'Australia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'BRN',
#    'Title': 'Brunei Darussalam',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'CHN',
#    'Title': 'China',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'COK',
#    'Title': 'Cook Islands',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'FJI',
#    'Title': 'Fiji',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'FSM',
#    'Title': 'Micronesia (Federated States of)',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'TON',
#    'Title': 'Tonga',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'TUV',
#    'Title': 'Tuvalu',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'VNM',
#    'Title': 'Viet Nam',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'VNM977',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'VUT',
#    'Title': 'Vanuatu',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'WSM',
#    'Title': 'Samoa',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'PHL',
#    'Title': 'Philippines',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'PLW',
#    'Title': 'Palau',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'PNG',
#    'Title': 'Papua New Guinea',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'SGP',
#    'Title': 'Singapore',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'SLB',
#    'Title': 'Solomon Islands',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'TKL',
#    'Title': 'Tokelau',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'MHL',
#    'Title': 'Marshall Islands',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'MNG',
#    'Title': 'Mongolia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'MYS',
#    'Title': 'Malaysia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'NIU',
#    'Title': 'Niue',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'NRU',
#    'Title': 'Nauru',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'NZL',
#    'Title': 'New Zealand',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'JPN',
#    'Title': 'Japan',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'KHM',
#    'Title': 'Cambodia',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'KIR',
#    'Title': 'Kiribati',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'KIR984',
#    'Title': 'SPATIAL_SYNONYM',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'KOR',
#    'Title': 'Republic of Korea',
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'LAO',
#    'Title': "Lao People's Democratic Republic",
#    'ParentDimension': 'REGION',
#    'Dimension': 'COUNTRY',
#    'ParentCode': 'WPR',
#    'ParentTitle': 'Western Pacific'},
#   {'Code': 'ME1',
#    'Title': 'The former state union Serbia and Montenegro',
#    'ParentDimension': None,
#    'Dimension': 'COUNTRY',
#    'ParentCode': None,
#    'ParentTitle': None},
#   {'Code': 'SDF',
#    'Title': 'Sudan (former)',
#    'ParentDimension': None,
#    'Dimension': 'COUNTRY',
#    'ParentCode': None,
#    'ParentTitle': None}]}

# %% [markdown]
# ## Retrieving the indicators list

# %% [markdown]
# Simply specifying the [/api/Indicator](https://ghoapi.azureedge.net/api/Indicator) URL will provide you with the list of indicators:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/Indicator")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator',
#  'value': [{'IndicatorCode': 'AIR_1',
#    'IndicatorName': 'Ambient air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_10',
#    'IndicatorName': "Ambient air pollution  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_11',
#    'IndicatorName': 'Household air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_12',
#    'IndicatorName': 'Household air pollution attributable deaths in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_13',
#    'IndicatorName': "Household air pollution attributable deaths per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_14',
#    'IndicatorName': "Household air pollution  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_15',
#    'IndicatorName': 'Household air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_16',
#    'IndicatorName': 'Household air pollution attributable DALYs in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_17',
#    'IndicatorName': 'Household air pollution attributable DALYs (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_18',
#    'IndicatorName': "Household air pollution  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_2',
#    'IndicatorName': 'Ambient air pollution (Annual PM10 [ug/m3])',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_2_1',
#    'IndicatorName': 'Ambient air pollution in urban areas (Annual PM<sub>10</sub> [&#956;g/m<sup>3</sup>])',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_3',
#    'IndicatorName': "Percentage of the total population living in cities > 100'000 inhabitants",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_3_1',
#    'IndicatorName': 'Percent of urban inhabitants living in cities covered by PM measurements',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_39',
#    'IndicatorName': 'Household air pollution attributable DALYs (per 100 000, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_4',
#    'IndicatorName': 'Ambient air pollution attributable deaths in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_41',
#    'IndicatorName': 'Ambient air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_42',
#    'IndicatorName': 'Ambient air pollution attributable death rate (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_43',
#    'IndicatorName': 'Ambient air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_44',
#    'IndicatorName': 'DALYs attributable to ambient air pollution (age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_45',
#    'IndicatorName': 'Ambient air pollution attributable YLLs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_5',
#    'IndicatorName': 'Ambient air pollution attributable death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_50',
#    'IndicatorName': 'Ambient air pollution attributable deaths (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_51',
#    'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_52',
#    'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_6',
#    'IndicatorName': "Ambient air pollution  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_7',
#    'IndicatorName': 'Ambient air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_8',
#    'IndicatorName': 'Ambient air pollution attributable DALYs  in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_9',
#    'IndicatorName': 'Ambient air pollution attributable DALYs  (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_90',
#    'IndicatorName': 'Ambient air pollution attributable DALYs  (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD01',
#    'IndicatorName': 'Functioning national AMR surveillance plan',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD02',
#    'IndicatorName': 'Establishment of National Coordination Centre (NCC)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD03',
#    'IndicatorName': 'Nomination of National Focal Point (NFP)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD04',
#    'IndicatorName': 'Establishment of national reference laboratory (NRL)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA01',
#    'IndicatorName': 'EQA provided to the national reference laboratory (NRL)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA02',
#    'IndicatorName': 'EQA provided for bacterial identification and AST',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA03',
#    'IndicatorName': 'EQA provided to local laboratories participating in GLASS',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA04',
#    'IndicatorName': 'GLASS pathogens testing covered by EQA',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA05',
#    'IndicatorName': 'Types of AST standards followed by countries',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_SURVL01',
#    'IndicatorName': 'Number of national surveillance sites in each country providing data to GLASS: hospital category',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_SURVL02',
#    'IndicatorName': 'Number of National surveillance sites in each country providing data to GLASS: outpatient facility category',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_SURVL03',
#    'IndicatorName': 'Number of local clinical laboratories in each country performing AST to support national AMR surveillance sites',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc1',
#    'IndicatorName': 'Antenatal care coverage - at least one visit (in the two or three years preceding the survey) (%',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc15',
#    'IndicatorName': 'Antenatal care coverage - at least one visit (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc4',
#    'IndicatorName': 'Antenatal care coverage - at least four visits (in the two or three years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc45',
#    'IndicatorName': 'Antenatal care coverage - at least four visits (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ANEMIANPW',
#    'IndicatorName': 'Prevalence of anaemia in non-pregnant women (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ANEMIAPW',
#    'IndicatorName': 'Prevalence of anaemia in pregnant women (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ANEMIAU5',
#    'IndicatorName': 'Prevalence of anaemia in children under 5 years (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'asfr1',
#    'IndicatorName': 'Adolescent fertility rate (per 1000 women aged 15-19 years)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'bcgv',
#    'IndicatorName': 'BCG immunization coverage among one-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_03',
#    'IndicatorName': 'Raised blood pressure (SBP>=140 OR DBP>=90) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_04',
#    'IndicatorName': 'Raised blood pressure (SBP>=140 OR DBP>=90) (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_05',
#    'IndicatorName': 'Mean systolic blood pressure (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_06',
#    'IndicatorName': 'Mean systolic blood pressure (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_airtime',
#    'IndicatorName': 'Process evaluation was employed to assess implementation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_aud_research',
#    'IndicatorName': 'Formative research was conducted',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_eval_impact',
#    'IndicatorName': 'Outcome evaluation was employed to assess effectiveness',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_gov_prog',
#    'IndicatorName': 'Campaign was part of a comprehensive tobacco control programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_mat_tested',
#    'IndicatorName': 'Campaign was pre-tested',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_media_planning',
#    'IndicatorName': 'Campaign utilized media planning',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_nat',
#    'IndicatorName': 'At least one national mass media campaign ran during the survey period',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_news',
#    'IndicatorName': 'Earned media/public relations were used to promote the campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_tv_radio',
#    'IndicatorName': 'Campaign aired on television and/or radio',
#    'Language': 'EN'},
#   {'IndicatorCode': 'carep',
#    'IndicatorName': 'Children aged < 5 years with pneumonia symptoms taken to a health facility (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CaseCS',
#    'IndicatorName': 'Congenital syphilis number of reported cases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CATARACTSURGICAL',
#    'IndicatorName': 'Cataract surgical coverage of adults aged 50 and over (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CATARACTSURGICALEFFECTIVE',
#    'IndicatorName': 'Effective cataract surgical coverage of adults aged 50 and over (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_1',
#    'IndicatorName': 'Climate change attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_2',
#    'IndicatorName': "Climate change attributable DALYs ('000)",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_3',
#    'IndicatorName': "Climate change attributable deaths per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_4',
#    'IndicatorName': "Climate change attributable DALYs per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_5',
#    'IndicatorName': "Climate change attributable deaths ('000) in children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_6',
#    'IndicatorName': "Climate change  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_7',
#    'IndicatorName': "Climate change attributable DALYs ('000) in children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_8',
#    'IndicatorName': "Climate change  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'cci',
#    'IndicatorName': 'Composite coverage index (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'cci2030',
#    'IndicatorName': 'Composite coverage index (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_1',
#    'IndicatorName': 'Poverty headcount ratio at $1.25 a day (PPP) (% of population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_2',
#    'IndicatorName': 'Human development index rank',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_3',
#    'IndicatorName': 'Gender inequality index rank',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHILDMORT5TO14',
#    'IndicatorName': 'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOL_01',
#    'IndicatorName': 'Raised total cholesterol (>= 5.0 mmol/L) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOL_02',
#    'IndicatorName': 'Raised total cholesterol (>= 5.0 mmol/L) (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOL_03',
#    'IndicatorName': 'Mean Total Cholesterol (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOL_04',
#    'IndicatorName': 'Mean Total Cholesterol (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOL_05',
#    'IndicatorName': 'Raised total cholesterol (&#8805; 6.2 mmol/L) (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOL_06',
#    'IndicatorName': 'Raised total cholesterol (&#8805; 6.2 mmol/L) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOLERA_0000000001',
#    'IndicatorName': 'Number of reported cases of cholera',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOLERA_0000000002',
#    'IndicatorName': 'Number of reported deaths from cholera',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOLERA_0000000003',
#    'IndicatorName': 'Cholera case fatality rate',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CM_01',
#    'IndicatorName': 'Number of under-five deaths (thousands)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CM_02',
#    'IndicatorName': 'Number of infant deaths (thousands)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CM_03',
#    'IndicatorName': 'Number of neonatal deaths (thousands)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'cpmo',
#    'IndicatorName': 'Contraceptive prevalence - modern methods (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'cpmt',
#    'IndicatorName': 'Contraceptive prevalence - modern and traditional methods (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'csection',
#    'IndicatorName': 'Births by caesarean section (in the two or three years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'csection5',
#    'IndicatorName': 'Births by caesarean section (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES00',
#    'IndicatorName': 'Total density per 100 000 population: Hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES01',
#    'IndicatorName': 'Total density per 100 000 population: Health posts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES02',
#    'IndicatorName': 'Total density per 100 000 population: Health centres',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES03',
#    'IndicatorName': 'Total density per 100 000 population: District/rural hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES04',
#    'IndicatorName': 'Total density per 100 000 population: Provincial hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES05',
#    'IndicatorName': 'Total density per 100 000 population: Specialized hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES06',
#    'IndicatorName': 'Availability of national standards or recommended lists of medical devices',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES07',
#    'IndicatorName': 'Types of lists recommending health technology for high burden diseases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES08',
#    'IndicatorName': 'Total density per million population: Magnetic Resonance Imaging',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES09',
#    'IndicatorName': 'Total density per million population: Computed tomography units',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES10',
#    'IndicatorName': 'Total density per million population: Positron Emission tomography',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES11',
#    'IndicatorName': 'Total density per million population: Gamma camera or Nuclear medicine',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES12',
#    'IndicatorName': 'Total density per million population: Linear Accelerator',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES13',
#    'IndicatorName': 'Type of nomenclature system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES14',
#    'IndicatorName': 'Use of nomenclature system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES15',
#    'IndicatorName': 'Health technology (medical device) national policy',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES16',
#    'IndicatorName': 'Unit in the Ministry of Health responsible for the management of medical devices',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES17',
#    'IndicatorName': 'Procurement of medical devices carried out at the national level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES18',
#    'IndicatorName': 'Availability of national list of approved medical devices for procurement or reimbursement',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES19',
#    'IndicatorName': 'National guidelines, policies or recommendations on the procurement of medical devices',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES20',
#    'IndicatorName': 'Availability of technical specifications of medical devices to support procurement or donations',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES21',
#    'IndicatorName': 'Total density per million population: Telecobalt Unit',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES22',
#    'IndicatorName': 'Total density per million population: Radiotherapy units',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES23',
#    'IndicatorName': 'Total density per million females aged from 50 to 69 years old: Mammography units',
#    'Language': 'EN'},
#   {'IndicatorCode': 'dptv',
#    'IndicatorName': 'DTP3 immunization coverage among one-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E_Group',
#    'IndicatorName': 'Enforcing bans on tobacco advertising, promotion and sponsorship',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E1_compliance',
#    'IndicatorName': 'Compliance of ban on advertising on national TV and radio',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E10_compliance',
#    'IndicatorName': 'Compliance of ban on promotional discounts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E10_promo_discounts',
#    'IndicatorName': 'Ban on promotional discounts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E11_brand_stretching',
#    'IndicatorName': 'Ban on non-tobacco goods AND services identified with tobacco brand names',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E11_compliance',
#    'IndicatorName': 'Compliance of ban on non-tobacco goods AND services identified with tobacco brand names',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E12_brand_sharing',
#    'IndicatorName': 'Ban on brand name of non-tobacco products used for tobacco product',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E12_compliance',
#    'IndicatorName': 'Compliance of ban on brand name of non-tobacco products used for tobacco product',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E13_brand_placement',
#    'IndicatorName': 'Ban on appearance of tobacco brands in TV and/or films (product placement)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E13_compliance',
#    'IndicatorName': 'Compliance of ban on appearance of tobacco brands in TV and/or films (product placement)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E14_compliance',
#    'IndicatorName': 'Compliance of ban on appearance of tobacco products in TV and/or films',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E14_prod_tv_films',
#    'IndicatorName': 'Appearance of tobacco products in TV and/or films',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15_compliance',
#    'IndicatorName': 'Compliance of ban on sponsored events',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15_sponsored_events',
#    'IndicatorName': 'Sponsored events',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E16_csr_promo_self',
#    'IndicatorName': 'Ban on tobacco companies/tobacco industry publicizing their “Corporate Social Responsibility” activities',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E17_csr_promo_others',
#    'IndicatorName': 'Ban on entities other than tobacco companies/tobacco industry publicizing the Corporate Social Responsibility activities of the tobacco companies',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E18_csr_anti_tobacco_media',
#    'IndicatorName': 'Ban on tobacco companies funding or making contributions (including in-kind contributions) to smoking prevention media campaigns, including those directed at youth',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E19_movies_anti_tob_ads',
#    'IndicatorName': 'Required anti-tobacco ads for any visual entertainment media product that depicts tobacco products, use or images',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E2_intl_tv_radio',
#    'IndicatorName': 'Ban on advertising: International TV and radio (broadcast from abroad, including satellite)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E21_vending_machines',
#    'IndicatorName': 'Complete ban on tobacco vending machines',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E22_subnational_exists',
#    'IndicatorName': 'Subnational bans on tobacco advertising, promotion and sponsorship',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E23_subnat_complete_bans_exist',
#    'IndicatorName': 'Subnational advertising, promotion and sponsorship bans - at least one jurisdiction has a comprehensive ban in place',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E24_internet_sales_ban',
#    'IndicatorName': 'Ban on internet sales of tobacco products',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E25_ban_display_pt_of_sale',
#    'IndicatorName': 'Ban on display of tobacco products at points of sale',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E26_direct_ad_fines',
#    'IndicatorName': 'Law requires fines for violations of direct advertising bans',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E27_indirect_ad_fines',
#    'IndicatorName': 'Law requires fines for violations of indirect advertising bans',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E3_compliance',
#    'IndicatorName': 'Compliance of ban on advertising on local magazines and newspapers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E3_nat_print',
#    'IndicatorName': 'Ban on advertising: Local magazines and newspapers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E4_intl_print',
#    'IndicatorName': 'Ban on advertising: International magazines and newspapers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E5_billboards',
#    'IndicatorName': 'Ban on advertising: Billboards and outdoor advertising',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E5_compliance',
#    'IndicatorName': 'Compliance of ban on advertising on billboards and outdoor advertising',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E6_compliance',
#    'IndicatorName': 'Compliance of ban on advertising at point of sale',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E6_pt_of_sale',
#    'IndicatorName': 'Ban on advertising: Point of sale',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E7_internet',
#    'IndicatorName': 'Ban on advertising: Internet',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E9_compliance',
#    'IndicatorName': 'Compliance of ban on free distribution of tobacco products in the mail or through other means',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E9_free_distrib',
#    'IndicatorName': 'Ban on free distribution of tobacco products in the mail or through other means',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ebreast',
#    'IndicatorName': 'Early initiation of breastfeeding (in the two or three years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ebreast5',
#    'IndicatorName': 'Early initiation of breastfeeding (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EC_direct_compliance',
#    'IndicatorName': 'Compliance with bans on direct advertising',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EC_indirect_compliance',
#    'IndicatorName': 'Compliance with bans on promotion and sponsorship',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFLIMITELECTRIC',
#    'IndicatorName': 'Electric field (kV/m)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFLIMITELECTRICLF',
#    'IndicatorName': 'Electric field (kV/m)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFLIMITELECTRICRF',
#    'IndicatorName': 'Electric field (V/m)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFLIMITMAGNETIC',
#    'IndicatorName': 'Magnetic flux density (microT)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFLIMITPOWERDENSITY',
#    'IndicatorName': 'Power density (W/m^2)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFPOWERFREQUENCY',
#    'IndicatorName': 'Power frequency (Hz)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFSAR',
#    'IndicatorName': 'Specific absorption rate (SAR) (W/kg)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFSTANDARD',
#    'IndicatorName': 'Existence of standards',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EMFSTATUS',
#    'IndicatorName': 'Legislative status',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_ADOBIRTH',
#    'IndicatorName': 'Adolescent birth rate (births per 1,000 women aged 15 to 19)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_ANC',
#    'IndicatorName': 'Coverage of antenatal care (4 visits)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_BMI30',
#    'IndicatorName': 'Prevalence of obesity',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_CONTRACEPTIVE',
#    'IndicatorName': 'Contraceptive prevalence rate among women married or in union',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_DTP3',
#    'IndicatorName': 'Coverage of DTP3 immunization',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_HIVPREV',
#    'IndicatorName': 'HIV prevalence',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_HOUSENETS',
#    'IndicatorName': 'Households that have a bednet for sleeping (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_INFANTMORT',
#    'IndicatorName': 'Infant mortality per 1 000 live births',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_ITN',
#    'IndicatorName': 'Households with at least one ITN for sleeping (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_ITNUNDER5',
#    'IndicatorName': 'Children under five who slept under an ITN the previous night (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_KNHIV',
#    'IndicatorName': 'Knowlege about sexual transmission of AIDS',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_MEAIMM',
#    'IndicatorName': 'Coverage of measles immunization',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_OPENDEFECATION',
#    'IndicatorName': 'Population not using any sanitation facility (open defecation) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_OVERWEIGHT',
#    'IndicatorName': 'Prevalence of (moderate or severe) overweight in children',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_SBA',
#    'IndicatorName': 'Coverage of skilled birth attendance',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_SLEPTNETS',
#    'IndicatorName': 'Women that slept under a bednet last night (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_SLUM',
#    'IndicatorName': 'Proportion of urban residents living in a slum area',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_SOLIDFUELS',
#    'IndicatorName': 'Households that use solid fuels for cooking (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_STUNT',
#    'IndicatorName': 'Prevalence of (moderate or severe) stunting in children',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_TOBACCO',
#    'IndicatorName': 'Prevalence of current cigarette smoking',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_U5MORT',
#    'IndicatorName': 'Under-five mortality per 1 000 live births',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_U5SLEPTNETS',
#    'IndicatorName': 'Children under five who slept under a bednet the previous night (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_UNDERWEIGHT',
#    'IndicatorName': 'Prevalence of (moderate or severe) underweight in children',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_URBPOP',
#    'IndicatorName': 'Population living in urban areas (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_URBSLUM',
#    'IndicatorName': 'Slum population in urban areas (% of total population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATER',
#    'IndicatorName': 'Population using improved drinking-water sources (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATERIMPROVED',
#    'IndicatorName': 'Households using an improved drinking-water source (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATERPIPED',
#    'IndicatorName': 'Households using a piped drinking-water source (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATERPREMISES',
#    'IndicatorName': 'Households using a piped onto premises drinking-water source (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_ESTIMATE_AVAILABLE',
#    'IndicatorName': 'Availability of estimates on large  health expenditures as a share of total expenditure or income',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_10_LEVEL_MILLION',
#    'IndicatorName': 'Total population with household expenditures on health greater than 10% of total household expenditure or income (SDG 3.8.2) (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_10_LEVEL_SH',
#    'IndicatorName': 'Total population with household expenditures on health greater than 10% of total household expenditure or income (SDG 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_10_POP',
#    'IndicatorName': 'Population with household expenditures on health greater than 10% of total household expenditure or income (SDG 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_25_LEVEL_MILLION',
#    'IndicatorName': 'Total population with household expenditures on health greater than 25% of total household expenditure or income  ( SDG indicator 3.8.2) (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_25_LEVEL_SH',
#    'IndicatorName': 'Total population with household expenditures on health greater than 25% of total household expenditure or income  ( SDG indicator 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_25_POP',
#    'IndicatorName': 'Population with household expenditures on health greater than 25% of total household expenditure or income  ( SDG indicator 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_190_LEVEL_MILLION',
#    'IndicatorName': 'Total population  pushed below the $1.90 a day  poverty line by household  health expenditures (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_190_LEVEL_SH',
#    'IndicatorName': 'Total population  pushed below the $1.90 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_310_LEVEL_MILLION',
#    'IndicatorName': 'Total population  pushed below the $3.10 a day  poverty line by household  health expenditures (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_310_LEVEL_SH',
#    'IndicatorName': 'Total population  pushed below the $3.10 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP190_POP',
#    'IndicatorName': 'Population  pushed below the $1.90 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP310_POP',
#    'IndicatorName': 'Population  pushed below the $3.10 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_190',
#    'IndicatorName': 'Increase in poverty gap  due to household  health expenditures at the $1.90 a day poverty line, in cents of international dollars',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_190_STD',
#    'IndicatorName': 'Increase in poverty gap due to household  health expenditures, expressed as a proportion of the $1.90 a-day poverty line (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_310',
#    'IndicatorName': 'Increase in poverty gap  due to household  health expenditures at the $3.10a day poverty line, in cents of international dollars',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_310_STD',
#    'IndicatorName': 'Increase in poverty gap due to household  health expenditures, expressed as a proportion of the 3.10 a-day poverty line (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMPOV_ESTIMATE_AVAILABLE',
#    'IndicatorName': 'Availability of estimates on impoverishment due to out-of-pocket health expenditures',
#    'Language': 'EN'},
#   {'IndicatorCode': 'fps',
#    'IndicatorName': 'Demand for family planning satisfied - modern and traditional methods (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'fpsmo',
#    'IndicatorName': 'Demand for family planning satisfied - modern methods (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'fullv',
#    'IndicatorName': 'Full immunization coverage among one-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GBD_DALYRTAGE',
#    'IndicatorName': 'Age-standardized DALYs (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x1',
#    'IndicatorName': 'National regulator approval of anti-dementia medication',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x1x1',
#    'IndicatorName': 'Availability of generic anti-dementia medication',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x1x2',
#    'IndicatorName': 'Availability of at least one anti-dementia medication approved for on-label use reimbursement',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x2_1AVAIL',
#    'IndicatorName': 'Availability of atleast one adult hygiene products for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x2_HOSUE',
#    'IndicatorName': 'Availability of atleast one housing adjustment for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x2_TECH',
#    'IndicatorName': 'Availability of  atleast one assistive technology for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x1',
#    'IndicatorName': 'Existence of dementia national nongovernmental organization',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x1',
#    'IndicatorName': 'Dementia nongovernmental organization equipped with office',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x2_1',
#    'IndicatorName': 'Dementia nongovernmental organization office branches (Sub-national)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x2_2',
#    'IndicatorName': 'Dementia nongovernmental organization office branches (Local)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x2_3',
#    'IndicatorName': 'Dementia nongovernmental organization office branches (National only)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x3',
#    'IndicatorName': 'Dementia nongovernmental organization staff primarily salaried/volunteer',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x5',
#    'IndicatorName': 'Provision of governmental funding to dementia nongovernmental organization for activities/services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x6',
#    'IndicatorName': "Dementia nongovernmental organization's involvement in policy development",
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x1',
#    'IndicatorName': 'Existence of dementia carer support services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x1x1',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia carer support services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x1x2',
#    'IndicatorName': 'Existence of dedicated resources for dementia carer support services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x1x3',
#    'IndicatorName': 'Existence of implementation plan for dementia carer support services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_1',
#    'IndicatorName': 'Existence of dementia carer training and education',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_2',
#    'IndicatorName': 'Existence of psycho-social supports for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_3',
#    'IndicatorName': 'Existence of respite care for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_4',
#    'IndicatorName': 'Existence of information on legal rights for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_5',
#    'IndicatorName': 'Existence of financial benefits/social protection for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_1',
#    'IndicatorName': 'Accessibility of dementia carer training and education [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_1NGO',
#    'IndicatorName': 'Majority provider of dementia carer training and education (NGO)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_1PRV',
#    'IndicatorName': 'Majority provider of dementia carer training and education (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_1PUB',
#    'IndicatorName': 'Majority provider of dementia carer training and education (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_2',
#    'IndicatorName': 'Accessibility of psycho-social supports for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_2NGO',
#    'IndicatorName': 'Majority provider of psycho-social supports for dementia carers (NGO)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_2PRV',
#    'IndicatorName': 'Majority provider of psycho-social supports for dementia carers (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_2PUB',
#    'IndicatorName': 'Majority provider of psycho-social supports for dementia carers (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_3',
#    'IndicatorName': 'Accessibility of respite care for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_3NGO',
#    'IndicatorName': 'Majority provider of respite care for dementia carers (NGO)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_3PRV',
#    'IndicatorName': 'Majority provider of respite care for dementia carers (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_3PUB',
#    'IndicatorName': 'Majority provider of respite care for dementia carers (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_4',
#    'IndicatorName': 'Accessibility of information on legal rights for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_4NGO',
#    'IndicatorName': 'Majority provider of information on legal rights for dementia carers (NGO)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_4PRV',
#    'IndicatorName': 'Majority provider of information on legal rights for dementia carers (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_4PUB',
#    'IndicatorName': 'Majority provider of information  on legal rights for dementia carers (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5',
#    'IndicatorName': 'Accessibility of financial benefits/social protection for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5NGO',
#    'IndicatorName': 'Majority provider of information on financial benefits/social protection for dementia carers (NGO)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5PRV',
#    'IndicatorName': 'Majority provider of information on financial benefits/social protection for dementia carers (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5PUB',
#    'IndicatorName': 'Majority provider of information  on financial benefits/social protection for dementia carers (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving training and education',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x2x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving psycho-social supports',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x3x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving respite care',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x4x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving information on legal rights',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x5x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving financial benefits/social protection',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x1',
#    'IndicatorName': 'Existence of at least one functioning dementia awareness campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x1x1',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia awareness campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x3',
#    'IndicatorName': 'Existence of at least one functioning risk reduction campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x3x1',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia risk reduction campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x1',
#    'IndicatorName': 'Availability of dementia-friendly initiatives that improve accessibility',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_1',
#    'IndicatorName': 'Existence of dementia-friendly initiative to improve accessibility of public spaces',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_2',
#    'IndicatorName': 'Existence of dementia-friendly initiative to improve accessibility of public transportation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_3',
#    'IndicatorName': 'Existence of dementia-friendly initiative for assistance with home modification',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_4',
#    'IndicatorName': 'Existence of dementia-friendly initiative with assistive technology for loss of capacity',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_5',
#    'IndicatorName': 'Existence of dementia-friendly initiative supporting community places for older people',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_6',
#    'IndicatorName': 'Existence of dementia-friendly initiative supporting social opportunities',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x1',
#    'IndicatorName': 'Inclusion of dementia training and education for non-health workers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_1',
#    'IndicatorName': 'Existence of dementia training for volunteers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_2',
#    'IndicatorName': 'Existence of dementia training for police and fire services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_3',
#    'IndicatorName': 'Existence of dementia training for first responders',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_4',
#    'IndicatorName': 'Existence of dementia training for legal professionals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_5',
#    'IndicatorName': 'Existence of dementia training for community workers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_6',
#    'IndicatorName': 'Existence of dementia training for school children',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_7',
#    'IndicatorName': 'Existence of dementia training for financial service staff',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_8',
#    'IndicatorName': 'Existence of dementia training for retail and hospitality staff',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1',
#    'IndicatorName': 'Routine monitoring of people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_1',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Clinical records)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_2',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Household surveys)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_3',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Administrative data)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_4',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Facility survey or records)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_other',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Other)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x2_1',
#    'IndicatorName': 'Electronic availability of data sources used to routinely monitor people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x2_2',
#    'IndicatorName': 'Data used to routinely monitor people with dementia can be disaggregated',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_1',
#    'IndicatorName': 'Availability of routine hospital admissions records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_2',
#    'IndicatorName': 'Availability of routine outpatient visit records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_3',
#    'IndicatorName': 'Availability of routine outpatient intervention and treatment records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_4',
#    'IndicatorName': 'Availability of routine pharmaceutical records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_5',
#    'IndicatorName': 'Availability of routine antipsychotic prescription records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x3',
#    'IndicatorName': 'Availability and status of dementia reporting in the past two years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x1',
#    'IndicatorName': 'Existence of a current dementia research plan/programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x1x1',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia research plan/programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2',
#    'IndicatorName': 'Dementia integrated into other national research plan/programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2x1_1',
#    'IndicatorName': 'Identification of other research plans in which dementia is integrated (Mental health)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2x1_2',
#    'IndicatorName': 'Identification of other research plans in which dementia is integrated (Ageing)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2x1_3',
#    'IndicatorName': 'Identification of other research plans in which dementia is integrated (Neuro or neurodegenerative disease)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2x1_4',
#    'IndicatorName': 'Identification of other research plans in which dementia is integrated (NCD)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2x2',
#    'IndicatorName': 'Implementation level [national/subnational] of research plan in which dementia is integrated',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q18x2',
#    'IndicatorName': 'Availability of funding for dementia-specific research plan/programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q18x2x1_1',
#    'IndicatorName': 'Total expenditure on dementia research (local currency, self-report)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q18x2x3_1',
#    'IndicatorName': 'Total expenditure on dementia basic research (local currency, self-report)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q18x2x3_2',
#    'IndicatorName': 'Total expenditure on dementia clinical/translational research (local currency, self-report)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q18x2x3_3',
#    'IndicatorName': 'Total expenditure on dementia implementation research (local currency, self-report)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q19x2',
#    'IndicatorName': 'Number of people with dementia involved in research routinely monitored',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q19x3',
#    'IndicatorName': 'Availability of investigational pharmaceutical trials for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q19x3x1_1',
#    'IndicatorName': 'Number of investigational pharmaceutical trials for dementia',
# ...
#    'IndicatorName': 'Coverage of national cervical cancer screening program (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_cervicalcancerpgmtype',
#    'IndicatorName': 'Type of national cervical cancer screening program',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_cervicalcancerscreening',
#    'IndicatorName': 'Existence of national screening program for cervical cancer',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CholMsmt',
#    'IndicatorName': 'General availability of total cholesterol measurement at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_coronary',
#    'IndicatorName': 'General availability of coronary bypass or stenting in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CRDPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for chronic respiratory diseases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CVDPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for cardiovascular diseases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_DiabetesReg',
#    'IndicatorName': 'Existence of a diabetes registry',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_DiabetesTest',
#    'IndicatorName': 'General availability of diabetes testing (by blood glucose measurement, OGTT, or HbA1c) at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_DiabPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for diabetes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_diabtest',
#    'IndicatorName': 'General availability of diabetes testing (by blood glucose measurement, OGTT) at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_dialysis',
#    'IndicatorName': 'General availability of dialysis in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_dietpaaware',
#    'IndicatorName': 'Implementation of diet and/or physical activity public awareness program',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_DietPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan to reduce unhealthy diet related to NCDs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_HbA1c',
#    'IndicatorName': 'General availability of diabetes testing (by HbA1c) at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_hpv',
#    'IndicatorName': 'Existence of national HPV vaccination programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Insulin',
#    'IndicatorName': 'General availability of insulin in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_integNCDplan',
#    'IndicatorName': 'Existence of an operational, multisectoral national NCD policy, strategy or action plan that integrates several NCDs and their risk factors',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Metformin',
#    'IndicatorName': 'General availability of metformin in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Mkting',
#    'IndicatorName': 'Existence of any policies on marketing of foods to children',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_MultisecComm',
#    'IndicatorName': 'Existence of a national multisectoral commission, agency or mechanism for NCDs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_NCDGuide',
#    'IndicatorName': 'Existence of evidence-based national guidelines/protocols/standards for the management of major NCDs through a primary care approach',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_NCDIndicators',
#    'IndicatorName': 'Existence of a set of national NCD indicators and has set time-bound national targets for these indicators',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_NCDUnit_Operational',
#    'IndicatorName': 'Existence of an Operational Unit, Branch, or Dept. in Ministry of Health with responsibility for NCDs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Nicotine',
#    'IndicatorName': 'General availability of nicotine replacement therapy in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_oralhealthplan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for oral health',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_OralMorph',
#    'IndicatorName': 'General availability of oral morphine in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_paaware',
#    'IndicatorName': 'Implementation of physical activity public awareness program',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_palliative_home',
#    'IndicatorName': 'General availability of palliative care in community or home-based care in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_palliative_prim',
#    'IndicatorName': 'General availability of palliative care in primary health care in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_PAPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan to reduce physical inactivity',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_photocoag',
#    'IndicatorName': 'General availability of retinal photocoagulation in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_PM3_Surv',
#    'IndicatorName': 'Has a STEPS survey or a comprehensive health examination survey every 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_renaltrans',
#    'IndicatorName': 'General availability of renal replacement by transplantation in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_rheum',
#    'IndicatorName': 'Provision for secondary prevention of rheumatic fever and rheumatic heart disease in more than 50% of public sector health facilities',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_rheumfollowup',
#    'IndicatorName': 'Has systems for follow-up/recall to deliver long-term penicillin prophylaxis to patients with rheumatic fever and rheumatic heart disease',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_rheumreg',
#    'IndicatorName': 'Existence of a register of patients who had rheumatic fever and rheumatic heart disease',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_riskstrat',
#    'IndicatorName': 'Availability of cardiovascular risk stratification in 50% or more primary health care facilities',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_SaltPol',
#    'IndicatorName': 'Existence of any policies to reduce population salt consumption',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_SatFat',
#    'IndicatorName': 'Existence of national policies on saturated fatty acids / trans-fats',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Spirom',
#    'IndicatorName': 'General availability of peak flow measurement spirometry at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_SSBTAX',
#    'IndicatorName': 'Existence of tax on sugar-sweetened beverages',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Statins',
#    'IndicatorName': 'General availability of statins in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Steroid',
#    'IndicatorName': 'General availability of steroid inhalers in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_stroke',
#    'IndicatorName': 'Provision for care of acute stroke and rehabilitation in more than 50% of public sector health facilities',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_sulphonylurea',
#    'IndicatorName': 'General availability of sulphonylurea(s) in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_SurvMonRep9NCD',
#    'IndicatorName': 'Existence of an NCD surveillance and monitoring system in place to enable reporting against the nine global NCD targets',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_targets',
#    'IndicatorName': 'Existence of a set of time-bound national targets based on WHO guidance',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Thiazide',
#    'IndicatorName': 'General availability of thiazide diuretics in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_thrombolytic',
#    'IndicatorName': 'General availability of thrombolytic therapy in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_TobPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan to decrease tobacco use',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_UrineAlbumin',
#    'IndicatorName': 'General availability of urine testing for albumin',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_DTH_TOT',
#    'IndicatorName': 'Total NCD Deaths (in thousands)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_GLUC_01',
#    'IndicatorName': 'Mean fasting blood glucose (mmol/l) (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_GLUC_02',
#    'IndicatorName': 'Mean fasting blood glucose (mmol/l) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_GLUC_03',
#    'IndicatorName': 'Raised fasting blood glucose (>= 7.0 mmol/L or on medication) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_GLUC_04',
#    'IndicatorName': 'Raised fasting blood glucose (>=7.0 mmol/L or on medication)(age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_PAA',
#    'IndicatorName': 'Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_PAC',
#    'IndicatorName': 'Prevalence of insufficient physical activity among adults aged 18+ years (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_PAC_ADO',
#    'IndicatorName': 'Insufficiently active (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_UNDER70',
#    'IndicatorName': 'NCD deaths under age 70 (percent of all NCD deaths)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCDMORT3070',
#    'IndicatorName': 'Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NHABASIS',
#    'IndicatorName': 'Basis for NHA estimate',
#    'Language': 'EN'},
#   {'IndicatorCode': 'nmr',
#    'IndicatorName': 'Neonatal mortality rate (deaths per 1000 live births)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTCP_agcy',
#    'IndicatorName': 'National agency for tobacco control exists',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTCP_budget_year',
#    'IndicatorName': 'Budget year',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTCP_curr',
#    'IndicatorName': 'Reported currency',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTCP_FTE',
#    'IndicatorName': 'Number of full-time equivalent staff in national agency',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTCP_govt_exp',
#    'IndicatorName': 'Annual budget for tobacco control in currency reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTCP_govt_obj',
#    'IndicatorName': 'Government objectives on tobacco control exist',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_1',
#    'IndicatorName': 'Number of new reported cases of Buruli ulcer',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_2',
#    'IndicatorName': 'Dracunculiasis certification status of countries at the beginning of the year',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_3',
#    'IndicatorName': 'Annual incidence of dracunculiasis cases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_4',
#    'IndicatorName': 'Number of new reported cases of human African trypanosomiasis (T.b. gambiense)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_5',
#    'IndicatorName': 'Number of new reported cases of human African trypanosomiasis (T.b. rhodesiense)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_6',
#    'IndicatorName': 'Status of elimination of trachoma as a public health problem',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_7',
#    'IndicatorName': 'Population in areas that warrant treatment with antibiotics, facial cleanliness and environmental improvement for elimination of trachoma as a public health problem',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_8',
#    'IndicatorName': 'Number of people who received treatment with antibiotics for trachoma',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_BEJELSTATUS',
#    'IndicatorName': 'Status of bejel endemicity',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEISHCEND',
#    'IndicatorName': 'Status of endemicity of cutaneous leishmaniasis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEISHCNUM',
#    'IndicatorName': 'Number of cases of cutaneous leishmaniasis reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEISHCNUM_IM',
#    'IndicatorName': 'Number of imported cases of cutaneous leishmaniasis reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEISHVEND',
#    'IndicatorName': 'Status of endemicity of visceral leishmaniasis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEISHVNUM',
#    'IndicatorName': 'Number of cases of visceral leishmaniasis reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEISHVNUM_IM',
#    'IndicatorName': 'Number of imported cases of visceral leishmaniasis reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR11',
#    'IndicatorName': 'Leprosy - Number of female new cases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR2',
#    'IndicatorName': 'Leprosy - New cases detection rate per 100 000 population',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR3',
#    'IndicatorName': 'Leprosy - Number of cases registered for treatment',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR4',
#    'IndicatorName': 'Leprosy - Registered cases per 10 000 population',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR5',
#    'IndicatorName': 'Leprosy - Number of new G2D cases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR7',
#    'IndicatorName': 'Leprosy - New leprosy cases with G2D rate per 1 000 000 population',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR8',
#    'IndicatorName': 'Leprosy - Number of new child (less than 15 years of age) cases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_LEPR9',
#    'IndicatorName': 'Leprosy - Number of new child (less than 15 years of age) cases detected with G2D',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_ONCHEMO',
#    'IndicatorName': 'Estimated number of individuals in the country requiring preventive chemotherapy for onchocerciasis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_ONCHSTATUS',
#    'IndicatorName': 'Status of endemicity of onchocerciasis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_ONCTREAT',
#    'IndicatorName': 'Reported number of individuals treated for onchocerciasis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_PINTASTATUS',
#    'IndicatorName': 'Status of pinta endemicity',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_RAB2',
#    'IndicatorName': 'Reported number of human rabies deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_TRA5',
#    'IndicatorName': 'Number of people operated for trachomatous trichiasis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_TSOL1',
#    'IndicatorName': 'Status of endemicity of Taenia solium',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_TSOL2',
#    'IndicatorName': 'Presence of porcine cysticercosis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_TSOL3',
#    'IndicatorName': 'Number of pigs in the country',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_TSOL4',
#    'IndicatorName': 'Practice of backyard pig production',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_YAWSEND',
#    'IndicatorName': 'Status of yaws endemicity',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NTD_YAWSNUM',
#    'IndicatorName': 'Number of cases of yaws reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NUTOVERWEIGHTNUM',
#    'IndicatorName': 'Overweight numbers (in millions)',
#    'Language': 'EN'},
#   ...]}

# %% [markdown]
# To select only the indicators which contain a specific text, query the data similar to the following example.
#
# In this example, all indicators containing **'Household'** were queried:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/Indicator?$filter=contains(IndicatorName,'Household')")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator',
#  'value': [{'IndicatorCode': 'AIR_11',
#    'IndicatorName': 'Household air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_12',
#    'IndicatorName': 'Household air pollution attributable deaths in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_13',
#    'IndicatorName': "Household air pollution attributable deaths per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_14',
#    'IndicatorName': "Household air pollution  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_15',
#    'IndicatorName': 'Household air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_16',
#    'IndicatorName': 'Household air pollution attributable DALYs in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_17',
#    'IndicatorName': 'Household air pollution attributable DALYs (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_18',
#    'IndicatorName': "Household air pollution  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_39',
#    'IndicatorName': 'Household air pollution attributable DALYs (per 100 000, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_51',
#    'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_52',
#    'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_HOUSENETS',
#    'IndicatorName': 'Households that have a bednet for sleeping (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_ITN',
#    'IndicatorName': 'Households with at least one ITN for sleeping (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_SOLIDFUELS',
#    'IndicatorName': 'Households that use solid fuels for cooking (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATERIMPROVED',
#    'IndicatorName': 'Households using an improved drinking-water source (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATERPIPED',
#    'IndicatorName': 'Households using a piped drinking-water source (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'EQ_WATERPREMISES',
#    'IndicatorName': 'Households using a piped onto premises drinking-water source (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_10_LEVEL_MILLION',
#    'IndicatorName': 'Total population with household expenditures on health greater than 10% of total household expenditure or income (SDG 3.8.2) (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_10_LEVEL_SH',
#    'IndicatorName': 'Total population with household expenditures on health greater than 10% of total household expenditure or income (SDG 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_10_POP',
#    'IndicatorName': 'Population with household expenditures on health greater than 10% of total household expenditure or income (SDG 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_25_LEVEL_MILLION',
#    'IndicatorName': 'Total population with household expenditures on health greater than 25% of total household expenditure or income  ( SDG indicator 3.8.2) (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_25_LEVEL_SH',
#    'IndicatorName': 'Total population with household expenditures on health greater than 25% of total household expenditure or income  ( SDG indicator 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_TOT_25_POP',
#    'IndicatorName': 'Population with household expenditures on health greater than 25% of total household expenditure or income  ( SDG indicator 3.8.2) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_190_LEVEL_MILLION',
#    'IndicatorName': 'Total population  pushed below the $1.90 a day  poverty line by household  health expenditures (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_190_LEVEL_SH',
#    'IndicatorName': 'Total population  pushed below the $1.90 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_310_LEVEL_MILLION',
#    'IndicatorName': 'Total population  pushed below the $3.10 a day  poverty line by household  health expenditures (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_310_LEVEL_SH',
#    'IndicatorName': 'Total population  pushed below the $3.10 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP190_POP',
#    'IndicatorName': 'Population  pushed below the $1.90 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP310_POP',
#    'IndicatorName': 'Population  pushed below the $3.10 a day  poverty line by household  health expenditures (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_190',
#    'IndicatorName': 'Increase in poverty gap  due to household  health expenditures at the $1.90 a day poverty line, in cents of international dollars',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_190_STD',
#    'IndicatorName': 'Increase in poverty gap due to household  health expenditures, expressed as a proportion of the $1.90 a-day poverty line (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_310',
#    'IndicatorName': 'Increase in poverty gap  due to household  health expenditures at the $3.10a day poverty line, in cents of international dollars',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_310_STD',
#    'IndicatorName': 'Increase in poverty gap due to household  health expenditures, expressed as a proportion of the 3.10 a-day poverty line (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_2',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Household surveys)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_15136',
#    'IndicatorName': 'Number of households sprayed at least once',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_15137',
#    'IndicatorName': 'Number of households targeted for spraying',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30515',
#    'IndicatorName': 'Household Net Possession - Percentage with more than one (Any type of mosquito net )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30516',
#    'IndicatorName': 'Household Net Possession - Average number of nets per household (Any type of mosquito net )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30517',
#    'IndicatorName': 'Household Net Possession - Percentage with at least one (Ever treated mosquito net )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30518',
#    'IndicatorName': 'Household Net Possession - Percentage with more than one (Ever treated mosquito net )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30519',
#    'IndicatorName': 'Household Net Possession - Average number of ever treated nets per household (Ever treated mosquito net )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30521',
#    'IndicatorName': 'Household Net Possession - Percentage with more than one (Insecticide treated mosquito nets (ITNs) )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_30522',
#    'IndicatorName': 'Household Net Possession - Average number of ITNs per household (Insecticide treated mosquito nets (ITNs) )',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA_HOUSEHOLDITNIRS',
#    'IndicatorName': 'Households with at least one insecticide-treated net (ITNs) or indoor residual spraying (IRS)(%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'SA_0000001476',
#    'IndicatorName': 'Alcohol expenditure as a per cent of total household expenditure',
#    'Language': 'EN'},
#   {'IndicatorCode': 'SA_0000001476_ARCHIVED',
#    'IndicatorName': 'Alcohol expenditure as a per cent of total household expenditure',
#    'Language': 'EN'},
#   {'IndicatorCode': 'SDGAIRBOD',
#    'IndicatorName': 'Ambient and household air pollution attributable death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'SDGAIRBODA',
#    'IndicatorName': 'Ambient and household air pollution attributable death rate (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_BNLFHU_FURIMP_HH',
#    'IndicatorName': 'Households further impoverished by out-of-pocket payments (relative poverty line reflecting basic needs: food, housing, utilities) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_BNLFHU_P_HH',
#    'IndicatorName': 'Households impoverished by out-of-pocket payments (relative poverty line reflecting basic needs: food, housing, utilities) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_REL_LEVEL_MILLION',
#    'IndicatorName': 'Total population pushed below a relative poverty line by household health expenditures (60% of median daily per capita consumption or income) (millions)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NPRELPL_POP',
#    'IndicatorName': 'Population pushed below a relative poverty line by household health expenditures (60% of median daily per capita consumption or income) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_PG_RELPL_STD',
#    'IndicatorName': 'Increase in poverty gap due to household health expenditures, expressed as a proportion of a relative poverty line (60% of median daily per capita consumption or income) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_BNLFHU_TOT_HH',
#    'IndicatorName': 'Households pushed below or further below a relative poverty line (reflecting basic needs: food, housing, utilities) by out-of-pocket payments (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_IMP_NP_REL_LEVEL_SH',
#    'IndicatorName': 'Total population pushed below a relative poverty line by household health expenditures (60% of median daily per capita consumption or income) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'FINPROTECTION_CATA_CTPFHU_40_HH',
#    'IndicatorName': 'Households with out-of-pocket payments greater than 40% of capacity to pay for health care (food, housing and utilities approach - developed by WHO/Europe) (%)',
#    'Language': 'EN'}]}

# %% [markdown]
# To select only the indicators that have a specific title, query the data using the following example.
#
# In this example, the indicator **'Ambient air pollution attributable deaths'** was queried:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/Indicator?$filter=IndicatorName eq 'Ambient air pollution attributable deaths'")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator',
#  'value': [{'IndicatorCode': 'AIR_1',
#    'IndicatorName': 'Ambient air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_41',
#    'IndicatorName': 'Ambient air pollution attributable deaths',
#    'Language': 'EN'}]}

# %% [markdown]
# ## Retrieving indicator data

# %% [markdown]
# Specify an indicator to download by specifying the indicator code. This will return all associated data for that specific indicator.
#
# Building on the previous example, take the code **WHOSIS_000001**, `"Life expectancy at birth"` and retrieve the data for this indicator using the following URL:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/WHOSIS_000001")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': [{'Id': 15578241,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.0',
#    'NumericValue': 42.99474,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.203+02:00'},
#   {'Id': 15578243,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.4',
#    'NumericValue': 48.38779,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.36+02:00'},
#   {'Id': 15578245,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '45.7',
#    'NumericValue': 45.70058,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.453+02:00'},
#   {'Id': 15578247,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.5',
#    'NumericValue': 43.48892,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.58+02:00'},
#   {'Id': 15578249,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.5',
#    'NumericValue': 49.4939,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.687+02:00'},
#   {'Id': 15578251,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.5',
#    'NumericValue': 46.4939,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.777+02:00'},
#   {'Id': 15578253,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.0',
#    'NumericValue': 46.02686,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.83+02:00'},
#   {'Id': 15578255,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.5',
#    'NumericValue': 51.45327,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.893+02:00'},
#   {'Id': 15578257,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.8',
#    'NumericValue': 48.76327,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.943+02:00'},
#   {'Id': 15578259,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '47.4',
#    'NumericValue': 47.43979,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.07+02:00'},
#   {'Id': 15578261,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '52.9',
#    'NumericValue': 52.90927,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.127+02:00'},
#   {'Id': 15578263,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '50.2',
#    'NumericValue': 50.20816,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.193+02:00'},
#   {'Id': 15578265,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.0',
#    'NumericValue': 49.0172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.253+02:00'},
#   {'Id': 15578267,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.64111,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.31+02:00'},
#   {'Id': 15578269,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.9',
#    'NumericValue': 51.87408,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.4+02:00'},
#   {'Id': 15578271,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.0',
#    'NumericValue': 51.02977,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.523+02:00'},
#   {'Id': 15578273,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.1',
#    'NumericValue': 57.07021,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.58+02:00'},
#   {'Id': 15578275,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.1',
#    'NumericValue': 54.10822,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.63+02:00'},
#   {'Id': 15578277,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.3',
#    'NumericValue': 53.29705,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.697+02:00'},
#   {'Id': 15578279,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.0',
#    'NumericValue': 59.96988,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.777+02:00'},
#   {'Id': 15578281,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.7',
#    'NumericValue': 56.70158,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.853+02:00'},
#   {'Id': 15578283,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.2',
#    'NumericValue': 55.24638,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.937+02:00'},
#   {'Id': 15578285,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.2',
#    'NumericValue': 62.19933,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.997+02:00'},
#   {'Id': 15578287,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.8',
#    'NumericValue': 58.7995,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.05+02:00'},
#   {'Id': 15578289,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.4',
#    'NumericValue': 56.40147,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.107+02:00'},
#   {'Id': 15578291,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.3',
#    'NumericValue': 63.26159,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.213+02:00'},
#   {'Id': 15578293,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.91484,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.307+02:00'},
#   {'Id': 15578295,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.1',
#    'NumericValue': 56.06949,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.367+02:00'},
#   {'Id': 15578297,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.7',
#    'NumericValue': 63.65812,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.447+02:00'},
#   {'Id': 15578299,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.94343,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.513+02:00'},
#   {'Id': 15578301,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04501,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.58+02:00'},
#   {'Id': 15578303,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.9',
#    'NumericValue': 64.89055,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.68+02:00'},
#   {'Id': 15578305,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6',
#    'NumericValue': 61.56371,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.763+02:00'},
#   {'Id': 15578307,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90235,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.82+02:00'},
#   {'Id': 15578309,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.7',
#    'NumericValue': 65.69534,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.883+02:00'},
#   {'Id': 15578311,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.4',
#    'NumericValue': 62.39735,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.973+02:00'},
#   {'Id': 15578313,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.7',
#    'NumericValue': 59.65667,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.04+02:00'},
#   {'Id': 15578315,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.3',
#    'NumericValue': 66.2644,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.13+02:00'},
#   {'Id': 15578317,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.1',
#    'NumericValue': 63.06204,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.203+02:00'},
#   {'Id': 15578319,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.4',
#    'NumericValue': 60.40749,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.273+02:00'},
#   {'Id': 15578321,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.7',
#    'NumericValue': 66.72172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.343+02:00'},
#   {'Id': 15578323,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.7',
#    'NumericValue': 63.67279,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.453+02:00'},
#   {'Id': 15578325,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.1',
#    'NumericValue': 61.13641,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.823+02:00'},
#   {'Id': 15578327,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.1',
#    'NumericValue': 67.076,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.89+02:00'},
#   {'Id': 15578329,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.2',
#    'NumericValue': 64.22249,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.97+02:00'},
#   {'Id': 15578331,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.9',
#    'NumericValue': 61.87112,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.053+02:00'},
#   {'Id': 15578333,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.4',
#    'NumericValue': 67.39024,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.187+02:00'},
#   {'Id': 15578335,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.8',
#    'NumericValue': 64.75297,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.28+02:00'},
#   {'Id': 18156496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.60243,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.39+02:00'},
#   {'Id': 18156497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.3',
#    'NumericValue': 55.29549,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.423+02:00'},
#   {'Id': 18156498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.45111,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.443+02:00'},
#   {'Id': 18156499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.9',
#    'NumericValue': 56.94814,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.47+02:00'},
#   {'Id': 18156500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.36723,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.497+02:00'},
#   {'Id': 18156501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.8',
#    'NumericValue': 57.81836,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.52+02:00'},
#   {'Id': 18156502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04882,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.547+02:00'},
#   {'Id': 18156503,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.38523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.58+02:00'},
#   {'Id': 18156504,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.0',
#    'NumericValue': 59.0,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.61+02:00'},
#   {'Id': 18156505,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.5',
#    'NumericValue': 59.45721,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.63+02:00'},
#   {'Id': 18156506,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.90372,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.65+02:00'},
#   {'Id': 18156507,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.45234,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.673+02:00'},
#   {'Id': 18156508,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.9',
#    'NumericValue': 60.94415,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.7+02:00'},
#   {'Id': 18156509,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.5',
#    'NumericValue': 61.49583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.727+02:00'},
#   {'Id': 18156510,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.7',
#    'NumericValue': 61.65874,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.75+02:00'},
#   {'Id': 18156511,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.8',
#    'NumericValue': 61.79883,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.777+02:00'},
#   {'Id': 18156512,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 61.04462,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.807+02:00'},
#   {'Id': 18156514,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.3',
#    'NumericValue': 57.29959,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.853+02:00'},
#   {'Id': 18156515,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.9',
#    'NumericValue': 57.85725,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.877+02:00'},
#   {'Id': 18156516,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.5',
#    'NumericValue': 58.49403,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.893+02:00'},
#   {'Id': 18156517,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.1',
#    'NumericValue': 59.06556,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.913+02:00'},
#   {'Id': 18156518,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.6',
#    'NumericValue': 59.57045,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.937+02:00'},
#   {'Id': 18156519,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.1',
#    'NumericValue': 60.08017,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.96+02:00'},
#   {'Id': 18156520,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.5066,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.987+02:00'},
#   {'Id': 18156521,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 60.97018,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.01+02:00'},
#   {'Id': 18156522,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6',
#    'NumericValue': 61.56165,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.033+02:00'},
#   {'Id': 18156523,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.1',
#    'NumericValue': 62.06646,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.053+02:00'},
#   {'Id': 18156524,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.5',
#    'NumericValue': 62.54279,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.08+02:00'},
#   {'Id': 18156525,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.1',
#    'NumericValue': 63.07744,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.103+02:00'},
#   {'Id': 18156526,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.6',
#    'NumericValue': 63.55457,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.123+02:00'},
#   {'Id': 18156527,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.1',
#    'NumericValue': 64.07648,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.143+02:00'},
#   {'Id': 18156528,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.4',
#    'NumericValue': 64.37848,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.163+02:00'},
#   {'Id': 18156529,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.7',
#    'NumericValue': 64.67819,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.187+02:00'},
#   {'Id': 18156530,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.5',
#    'NumericValue': 64.49557,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.207+02:00'},
#   {'Id': 18156532,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.9',
#    'NumericValue': 55.89618,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.25+02:00'},
#   {'Id': 18156533,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.52523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.27+02:00'},
#   {'Id': 18156534,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.43997,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.29+02:00'},
#   {'Id': 18156535,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 57.971,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.31+02:00'},
#   {'Id': 18156536,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.42978,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.333+02:00'},
#   {'Id': 18156537,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90924,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.353+02:00'},
#   {'Id': 18156538,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.2',
#    'NumericValue': 59.23066,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.37+02:00'},
#   {'Id': 18156539,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.6',
#    'NumericValue': 59.62808,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.39+02:00'},
#   {'Id': 18156540,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.2',
#    'NumericValue': 60.23545,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.42+02:00'},
#   {'Id': 18156541,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
# ...
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.0',
#    'NumericValue': 72.02805,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.91+02:00'},
#   {'Id': 18157472,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.4',
#    'NumericValue': 72.38357,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.93+02:00'},
#   {'Id': 18157473,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.6',
#    'NumericValue': 71.61191,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.957+02:00'},
#   {'Id': 18157474,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.5',
#    'NumericValue': 72.52351,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.977+02:00'},
#   {'Id': 18157475,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3',
#    'NumericValue': 72.33039,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56+02:00'},
#   {'Id': 18157476,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.0',
#    'NumericValue': 72.95933,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.02+02:00'},
#   {'Id': 18157477,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.3',
#    'NumericValue': 73.25368,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.04+02:00'},
#   {'Id': 18157478,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.5',
#    'NumericValue': 73.49396,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.06+02:00'},
#   {'Id': 18157479,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9',
#    'NumericValue': 73.93802,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.08+02:00'},
#   {'Id': 18157480,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.0',
#    'NumericValue': 74.03307,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.103+02:00'},
#   {'Id': 18157481,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.11275,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.127+02:00'},
#   {'Id': 18157482,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.13898,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.15+02:00'},
#   {'Id': 18157483,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.5',
#    'NumericValue': 74.52892,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.173+02:00'},
#   {'Id': 18157484,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.8',
#    'NumericValue': 74.75126,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.193+02:00'},
#   {'Id': 18157486,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.1',
#    'NumericValue': 77.09014,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.233+02:00'},
#   {'Id': 18157487,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.69583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.257+02:00'},
#   {'Id': 18157488,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.8',
#    'NumericValue': 77.78509,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.277+02:00'},
#   {'Id': 18157489,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.6',
#    'NumericValue': 77.57087,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.303+02:00'},
#   {'Id': 18157490,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.5',
#    'NumericValue': 77.54809,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.323+02:00'},
#   {'Id': 18157491,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.3',
#    'NumericValue': 77.28371,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.347+02:00'},
#   {'Id': 18157492,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9',
#    'NumericValue': 77.91827,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.367+02:00'},
#   {'Id': 18157493,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.72093,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.39+02:00'},
#   {'Id': 18157494,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.5',
#    'NumericValue': 78.5369,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.437+02:00'},
#   {'Id': 18157495,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.4',
#    'NumericValue': 78.40302,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.473+02:00'},
#   {'Id': 18157496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6',
#    'NumericValue': 78.5621,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.5+02:00'},
#   {'Id': 18157497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.1',
#    'NumericValue': 79.13873,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.52+02:00'},
#   {'Id': 18157498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.2',
#    'NumericValue': 79.24512,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.55+02:00'},
#   {'Id': 18157499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3',
#    'NumericValue': 79.29684,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.57+02:00'},
#   {'Id': 18157500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3',
#    'NumericValue': 79.32494,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.59+02:00'},
#   {'Id': 18157501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.6',
#    'NumericValue': 79.57848,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.617+02:00'},
#   {'Id': 18157502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.8',
#    'NumericValue': 79.75803,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.64+02:00'},
#   ...]}

# %% [markdown]
# ## Filtering data

# %% [markdown]
# You can filter the data returned by the web service by identifying specific dimensions and dimension codes that you wish to include or exclude. Use the URL parameter `filter` with a list of fully qualified dimension codes separated by operator 'and'.
#
# Continuing to build on the query from the previous example, if you wish to see the life expectancy at birth data for males only, the query is:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/WHOSIS_000001?$filter=Dim1 eq 'MLE'")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': [{'Id': 15578241,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.0',
#    'NumericValue': 42.99474,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.203+02:00'},
#   {'Id': 15578247,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.5',
#    'NumericValue': 43.48892,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.58+02:00'},
#   {'Id': 15578253,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.0',
#    'NumericValue': 46.02686,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.83+02:00'},
#   {'Id': 15578259,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '47.4',
#    'NumericValue': 47.43979,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.07+02:00'},
#   {'Id': 15578265,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.0',
#    'NumericValue': 49.0172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.253+02:00'},
#   {'Id': 15578271,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.0',
#    'NumericValue': 51.02977,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.523+02:00'},
#   {'Id': 15578277,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.3',
#    'NumericValue': 53.29705,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.697+02:00'},
#   {'Id': 15578283,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.2',
#    'NumericValue': 55.24638,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.937+02:00'},
#   {'Id': 15578289,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.4',
#    'NumericValue': 56.40147,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.107+02:00'},
#   {'Id': 15578295,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.1',
#    'NumericValue': 56.06949,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.367+02:00'},
#   {'Id': 15578301,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04501,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.58+02:00'},
#   {'Id': 15578307,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90235,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.82+02:00'},
#   {'Id': 15578313,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.7',
#    'NumericValue': 59.65667,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.04+02:00'},
#   {'Id': 15578319,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.4',
#    'NumericValue': 60.40749,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.273+02:00'},
#   {'Id': 15578325,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.1',
#    'NumericValue': 61.13641,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.823+02:00'},
#   {'Id': 15578331,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.9',
#    'NumericValue': 61.87112,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.053+02:00'},
#   {'Id': 18156496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.60243,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.39+02:00'},
#   {'Id': 18156497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.3',
#    'NumericValue': 55.29549,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.423+02:00'},
#   {'Id': 18156498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.45111,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.443+02:00'},
#   {'Id': 18156499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.9',
#    'NumericValue': 56.94814,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.47+02:00'},
#   {'Id': 18156500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.36723,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.497+02:00'},
#   {'Id': 18156501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.8',
#    'NumericValue': 57.81836,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.52+02:00'},
#   {'Id': 18156502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04882,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.547+02:00'},
#   {'Id': 18156503,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.38523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.58+02:00'},
#   {'Id': 18156504,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.0',
#    'NumericValue': 59.0,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.61+02:00'},
#   {'Id': 18156505,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.5',
#    'NumericValue': 59.45721,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.63+02:00'},
#   {'Id': 18156506,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.90372,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.65+02:00'},
#   {'Id': 18156507,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.45234,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.673+02:00'},
#   {'Id': 18156508,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.9',
#    'NumericValue': 60.94415,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.7+02:00'},
#   {'Id': 18156509,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.5',
#    'NumericValue': 61.49583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.727+02:00'},
#   {'Id': 18156510,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.7',
#    'NumericValue': 61.65874,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.75+02:00'},
#   {'Id': 18156511,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.8',
#    'NumericValue': 61.79883,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.777+02:00'},
#   {'Id': 18156512,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 61.04462,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.807+02:00'},
#   {'Id': 18156550,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '45.2',
#    'NumericValue': 45.17575,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.67+02:00'},
#   {'Id': 18156551,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.0',
#    'NumericValue': 45.98928,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.697+02:00'},
#   {'Id': 18156552,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '47.3',
#    'NumericValue': 47.31633,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.72+02:00'},
#   {'Id': 18156553,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.4',
#    'NumericValue': 48.39068,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.747+02:00'},
#   {'Id': 18156554,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.4',
#    'NumericValue': 49.39206,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.773+02:00'},
#   {'Id': 18156555,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '50.6',
#    'NumericValue': 50.60378,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.793+02:00'},
#   {'Id': 18156556,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.7',
#    'NumericValue': 51.66042,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.82+02:00'},
#   {'Id': 18156557,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '52.8',
#    'NumericValue': 52.76512,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.843+02:00'},
#   {'Id': 18156558,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.9',
#    'NumericValue': 53.87804,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.867+02:00'},
#   {'Id': 18156559,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.0',
#    'NumericValue': 55.01255,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.893+02:00'},
#   {'Id': 18156560,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.1',
#    'NumericValue': 56.14198,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.917+02:00'},
#   {'Id': 18156561,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.2',
#    'NumericValue': 57.18634,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.94+02:00'},
#   {'Id': 18156562,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.1',
#    'NumericValue': 58.0757,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.977+02:00'},
#   {'Id': 18156563,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.8',
#    'NumericValue': 58.76226,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:33.003+02:00'},
#   {'Id': 18156564,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.4',
#    'NumericValue': 59.3635,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:33.03+02:00'},
#   {'Id': 18156565,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.88823,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:33.057+02:00'},
#   {'Id': 18156566,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.3',
#    'NumericValue': 60.32734,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:33.083+02:00'},
#   {'Id': 18156604,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.4',
#    'NumericValue': 70.42431,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:33.987+02:00'},
#   {'Id': 18156605,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.6',
#    'NumericValue': 71.59666,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.003+02:00'},
#   {'Id': 18156606,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.4',
#    'NumericValue': 71.38121,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.027+02:00'},
#   {'Id': 18156607,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.8',
#    'NumericValue': 70.83972,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.047+02:00'},
#   {'Id': 18156608,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.0',
#    'NumericValue': 71.00983,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.067+02:00'},
#   {'Id': 18156609,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.6',
#    'NumericValue': 71.59837,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.087+02:00'},
#   {'Id': 18156610,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.8',
#    'NumericValue': 71.79563,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.11+02:00'},
#   {'Id': 18156611,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.9',
#    'NumericValue': 71.9333,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.133+02:00'},
#   {'Id': 18156612,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.1',
#    'NumericValue': 72.08276,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.153+02:00'},
#   {'Id': 18156613,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3',
#    'NumericValue': 72.303,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.173+02:00'},
#   {'Id': 18156614,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.5',
#    'NumericValue': 72.50727,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.2+02:00'},
#   {'Id': 18156615,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.6',
#    'NumericValue': 72.64958,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.22+02:00'},
#   {'Id': 18156616,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.0',
#    'NumericValue': 72.96376,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.24+02:00'},
#   {'Id': 18156617,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.6',
#    'NumericValue': 73.5537,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.263+02:00'},
#   {'Id': 18156618,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.0',
#    'NumericValue': 74.02616,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.287+02:00'},
#   {'Id': 18156619,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.2',
#    'NumericValue': 74.23715,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.313+02:00'},
#   {'Id': 18156620,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.3',
#    'NumericValue': 74.33482,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.337+02:00'},
#   {'Id': 18156658,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.5',
#    'NumericValue': 73.50984,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.32+02:00'},
#   {'Id': 18156659,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.7',
#    'NumericValue': 73.67609,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.35+02:00'},
#   {'Id': 18156660,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9',
#    'NumericValue': 73.85414,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.377+02:00'},
#   {'Id': 18156661,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.0',
#    'NumericValue': 74.04794,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.4+02:00'},
#   {'Id': 18156662,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.3',
#    'NumericValue': 74.28732,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.433+02:00'},
#   {'Id': 18156663,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.6',
#    'NumericValue': 74.57171,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.46+02:00'},
#   {'Id': 18156664,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.8',
#    'NumericValue': 74.79778,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.487+02:00'},
#   {'Id': 18156665,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.0',
#    'NumericValue': 75.04089,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.527+02:00'},
#   {'Id': 18156666,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.2',
#    'NumericValue': 75.24821,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.553+02:00'},
#   {'Id': 18156667,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.4',
#    'NumericValue': 75.44578,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.58+02:00'},
#   {'Id': 18156668,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.6',
#    'NumericValue': 75.6143,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.603+02:00'},
#   {'Id': 18156669,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.8',
#    'NumericValue': 75.81395,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.63+02:00'},
#   {'Id': 18156670,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.0',
#    'NumericValue': 75.9721,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.657+02:00'},
#   {'Id': 18156671,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.1',
#    'NumericValue': 76.1003,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.687+02:00'},
#   {'Id': 18156672,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.2',
#    'NumericValue': 76.22818,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.713+02:00'},
#   {'Id': 18156673,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.4',
#    'NumericValue': 76.36364,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.737+02:00'},
#   {'Id': 18156674,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.5',
#    'NumericValue': 76.48746,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.767+02:00'},
#   {'Id': 18156712,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.2',
#    'NumericValue': 70.2484,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:36.803+02:00'},
#   {'Id': 18156713,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.3',
#    'NumericValue': 70.33872,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:36.833+02:00'},
#   {'Id': 18156714,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.4',
#    'NumericValue': 70.44347,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:36.857+02:00'},
#   {'Id': 18156715,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.6',
#    'NumericValue': 70.64646,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:36.88+02:00'},
#   {'Id': 18156716,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.4',
#    'NumericValue': 71.36794,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:36.9+02:00'},
#   {'Id': 18156717,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.6',
#    'NumericValue': 71.55481,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
# ...
#    'Date': '2018-04-06T10:39:45.62+02:00'},
#   {'Id': 18159523,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.1',
#    'NumericValue': 76.11478,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.64+02:00'},
#   {'Id': 18159524,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.0',
#    'NumericValue': 76.95907,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.67+02:00'},
#   {'Id': 18159525,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.9',
#    'NumericValue': 76.89451,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.693+02:00'},
#   {'Id': 18159526,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.4',
#    'NumericValue': 77.42674,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.717+02:00'},
#   {'Id': 18159527,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.69022,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.733+02:00'},
#   {'Id': 18159528,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9',
#    'NumericValue': 77.87883,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.76+02:00'},
#   {'Id': 18159529,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.0',
#    'NumericValue': 78.04598,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.78+02:00'},
#   {'Id': 18159530,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.2',
#    'NumericValue': 78.20197,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.8+02:00'},
#   {'Id': 18159531,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6',
#    'NumericValue': 78.6347,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.82+02:00'},
#   {'Id': 18159532,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.8',
#    'NumericValue': 78.83018,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.84+02:00'},
#   {'Id': 18159533,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.2',
#    'NumericValue': 79.17949,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.863+02:00'},
#   {'Id': 18159534,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.7',
#    'NumericValue': 79.67302,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.897+02:00'},
#   {'Id': 18159535,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.8',
#    'NumericValue': 79.82015,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.92+02:00'},
#   {'Id': 18159536,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.1',
#    'NumericValue': 80.14397,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.94+02:00'},
#   {'Id': 18159574,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.1',
#    'NumericValue': 66.11646,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:46.93+02:00'},
#   {'Id': 18159575,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.2',
#    'NumericValue': 66.22408,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:46.957+02:00'},
#   {'Id': 18159576,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.0',
#    'NumericValue': 65.02071,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:46.983+02:00'},
#   {'Id': 18159577,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.5',
#    'NumericValue': 66.49333,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.01+02:00'},
#   {'Id': 18159578,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.6',
#    'NumericValue': 66.58649,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.033+02:00'},
#   {'Id': 18159579,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.7',
#    'NumericValue': 66.73328,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.06+02:00'},
#   {'Id': 18159580,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.0',
#    'NumericValue': 66.9601,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.08+02:00'},
#   {'Id': 18159581,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.1',
#    'NumericValue': 67.08275,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.103+02:00'},
#   {'Id': 18159582,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.2',
#    'NumericValue': 67.24914,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.127+02:00'},
#   {'Id': 18159583,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.4',
#    'NumericValue': 67.44627,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.147+02:00'},
#   {'Id': 18159584,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.6',
#    'NumericValue': 67.56206,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.167+02:00'},
#   {'Id': 18159585,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.7',
#    'NumericValue': 67.69312,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.19+02:00'},
#   {'Id': 18159586,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.8',
#    'NumericValue': 67.81568,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.213+02:00'},
#   {'Id': 18159587,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.0',
#    'NumericValue': 67.96698,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.24+02:00'},
#   {'Id': 18159588,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.0',
#    'NumericValue': 68.00634,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.263+02:00'},
#   ...]}

# %% [markdown]
# This query still returns a lof of data, but you can filter it further.
#
# For example, if we wish to know the life expectancy for males for the year 2011, we will add the following codes to the filter: `and TimeDim eq 2011`:

# %%
response = requests.get("https://ghoapi.azureedge.net/api/WHOSIS_000001?$filter=Dim1 eq 'MLE' and TimeDim eq 2011")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': [{'Id': 15578307,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90235,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.82+02:00'},
#   {'Id': 18156507,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.45234,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.673+02:00'},
#   {'Id': 18156561,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.2',
#    'NumericValue': 57.18634,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:32.94+02:00'},
#   {'Id': 18156615,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ALB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.6',
#    'NumericValue': 72.64958,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:34.22+02:00'},
#   {'Id': 18156669,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.8',
#    'NumericValue': 75.81395,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:35.63+02:00'},
#   {'Id': 18156723,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.5',
#    'NumericValue': 72.51418,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:37.083+02:00'},
#   {'Id': 18156777,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.8',
#    'NumericValue': 69.79819,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:38.383+02:00'},
#   {'Id': 18156831,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ATG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.6',
#    'NumericValue': 72.62591,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:39.8+02:00'},
#   {'Id': 18156885,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AUS',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.1',
#    'NumericValue': 80.09598,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:41.063+02:00'},
#   {'Id': 18156939,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AUT',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.3',
#    'NumericValue': 78.31915,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:42.293+02:00'},
#   {'Id': 18156993,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AZE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.9',
#    'NumericValue': 68.88554,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:43.59+02:00'},
#   {'Id': 18157047,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BDI',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.8',
#    'NumericValue': 56.80119,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:45.22+02:00'},
#   {'Id': 18157101,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BEL',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9',
#    'NumericValue': 77.8784,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:46.47+02:00'},
#   {'Id': 18157155,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BEN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.2',
#    'NumericValue': 58.2109,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:47.76+02:00'},
#   {'Id': 18157209,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BFA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.1',
#    'NumericValue': 57.06628,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:49.123+02:00'},
#   {'Id': 18157263,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BGD',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.2',
#    'NumericValue': 69.21876,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:50.56+02:00'},
#   {'Id': 18157317,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BGR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.7',
#    'NumericValue': 70.70963,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:52.053+02:00'},
#   {'Id': 18157371,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BHR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.5',
#    'NumericValue': 76.54294,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:53.447+02:00'},
#   {'Id': 18157425,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BHS',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3',
#    'NumericValue': 72.28388,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:54.78+02:00'},
#   {'Id': 18157479,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9',
#    'NumericValue': 73.93802,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.08+02:00'},
#   {'Id': 18157533,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BLR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.6',
#    'NumericValue': 64.63404,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:57.453+02:00'},
#   {'Id': 18157587,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BLZ',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.4',
#    'NumericValue': 67.4318,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:38:58.82+02:00'},
#   {'Id': 18157641,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BOL',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.6',
#    'NumericValue': 67.57635,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:00.1+02:00'},
#   {'Id': 18157695,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.9',
#    'NumericValue': 69.94624,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:01.43+02:00'},
#   {'Id': 18157749,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.4',
#    'NumericValue': 72.39668,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:02.757+02:00'},
#   {'Id': 18157803,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.4',
#    'NumericValue': 75.42695,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:04.073+02:00'},
#   {'Id': 18157857,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BTN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.8',
#    'NumericValue': 68.76727,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:05.47+02:00'},
#   {'Id': 18157911,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.3',
#    'NumericValue': 59.29792,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:39:06.85+02:00'},
#   {'Id': 18157965,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAF',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.4',
#    'NumericValue': 49.44088,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:39:08.087+02:00'},
#   {'Id': 18158019,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.8',
#    'NumericValue': 79.75449,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:09.393+02:00'},
#   {'Id': 18158073,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CHE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.5',
#    'NumericValue': 80.45323,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:10.603+02:00'},
#   {'Id': 18158127,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CHL',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '75.9',
#    'NumericValue': 75.94231,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:12.007+02:00'},
#   {'Id': 18158181,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CHN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.05267,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:13.26+02:00'},
#   {'Id': 18158235,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CIV',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.9',
#    'NumericValue': 51.94816,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:14.523+02:00'},
#   {'Id': 18158289,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CMR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.62125,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:39:15.757+02:00'},
#   {'Id': 18158343,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COD',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.8',
#    'NumericValue': 56.81598,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:17.097+02:00'},
#   {'Id': 18158397,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.2',
#    'NumericValue': 61.24132,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:39:18.343+02:00'},
#   {'Id': 18158451,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COL',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.6',
#    'NumericValue': 70.64297,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:19.557+02:00'},
#   {'Id': 18158505,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.7',
#    'NumericValue': 60.74894,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:20.753+02:00'},
#   {'Id': 18158559,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CPV',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.2',
#    'NumericValue': 70.16167,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:22.033+02:00'},
#   {'Id': 18158613,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CRI',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.5',
#    'NumericValue': 76.48418,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:23.27+02:00'},
#   {'Id': 18158667,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CUB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.8',
#    'NumericValue': 76.78998,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:24.683+02:00'},
#   {'Id': 18158721,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CYP',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.2',
#    'NumericValue': 78.18288,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:26.02+02:00'},
#   {'Id': 18158775,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CZE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.8',
#    'NumericValue': 74.83856,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:27.29+02:00'},
#   {'Id': 18158829,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DEU',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9',
#    'NumericValue': 77.94756,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:28.63+02:00'},
#   {'Id': 18158883,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DJI',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.6',
#    'NumericValue': 60.55463,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:29.993+02:00'},
#   {'Id': 18158937,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.0',
#    'NumericValue': 77.95023,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:31.27+02:00'},
#   {'Id': 18158991,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DOM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.4',
#    'NumericValue': 69.36928,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:32.51+02:00'},
#   {'Id': 18159045,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DZA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.6',
#    'NumericValue': 74.59778,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:33.72+02:00'},
#   {'Id': 18159099,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ECU',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.7',
#    'NumericValue': 72.74094,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:34.94+02:00'},
#   {'Id': 18159153,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'EGY',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.6',
#    'NumericValue': 67.63323,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:36.19+02:00'},
#   {'Id': 18159207,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ERI',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.9',
#    'NumericValue': 60.87431,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:37.417+02:00'},
#   {'Id': 18159261,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ESP',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.4',
#    'NumericValue': 79.41276,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:38.81+02:00'},
#   {'Id': 18159315,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'EST',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.2',
#    'NumericValue': 71.24638,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:40.36+02:00'},
#   {'Id': 18159369,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ETH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.8',
#    'NumericValue': 60.83232,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:41.61+02:00'},
#   {'Id': 18159423,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FIN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.3',
#    'NumericValue': 77.28208,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:43.25+02:00'},
#   {'Id': 18159477,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FJI',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.6',
#    'NumericValue': 66.57015,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:44.567+02:00'},
#   {'Id': 18159531,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FRA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6',
#    'NumericValue': 78.6347,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:45.82+02:00'},
#   {'Id': 18159585,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.7',
#    'NumericValue': 67.69312,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:47.19+02:00'},
#   {'Id': 18159639,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GAB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.2',
#    'NumericValue': 62.22839,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:39:48.483+02:00'},
#   {'Id': 18159693,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GBR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.1',
#    'NumericValue': 79.10542,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:49.77+02:00'},
#   {'Id': 18159747,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GEO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.4',
#    'NumericValue': 68.36183,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:51.05+02:00'},
#   {'Id': 18159801,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GHA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.8',
#    'NumericValue': 60.83463,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:52.257+02:00'},
#   {'Id': 18159855,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GIN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.1',
#    'NumericValue': 57.06297,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:53.663+02:00'},
#   {'Id': 18159909,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GMB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.3',
#    'NumericValue': 59.26424,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:55.203+02:00'},
#   {'Id': 18159963,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GNB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.2',
#    'NumericValue': 56.19179,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:39:56.417+02:00'},
#   {'Id': 18160017,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GNQ',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.4',
#    'NumericValue': 56.44788,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:39:57.59+02:00'},
#   {'Id': 18160071,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRC',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.0',
#    'NumericValue': 78.00837,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:39:58.767+02:00'},
#   {'Id': 18160125,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRD',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.4',
#    'NumericValue': 70.43665,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:39:59.96+02:00'},
#   {'Id': 18160179,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GTM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.4',
#    'NumericValue': 68.40501,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:01.35+02:00'},
#   {'Id': 18160233,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GUY',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.2',
#    'NumericValue': 63.20925,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:02.533+02:00'},
#   {'Id': 18160287,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HND',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.9',
#    'NumericValue': 71.90138,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:03.783+02:00'},
#   {'Id': 18160341,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HRV',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.8',
#    'NumericValue': 73.80737,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:05.083+02:00'},
#   {'Id': 18160395,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HTI',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 60.96023,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:40:06.363+02:00'},
#   {'Id': 18160449,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HUN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.0',
#    'NumericValue': 70.9863,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:07.52+02:00'},
#   {'Id': 18160503,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IDN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.3',
#    'NumericValue': 66.30301,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:10.68+02:00'},
#   {'Id': 18160557,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IND',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.1',
#    'NumericValue': 66.06249,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:15.653+02:00'},
#   {'Id': 18160611,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRL',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6',
#    'NumericValue': 78.60396,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:16.963+02:00'},
#   {'Id': 18160665,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.3',
#    'NumericValue': 73.31023,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:18.283+02:00'},
#   {'Id': 18160719,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRQ',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.1',
#    'NumericValue': 69.11356,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:19.92+02:00'},
#   {'Id': 18160773,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ISL',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.6',
#    'NumericValue': 80.62821,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:21.207+02:00'},
#   {'Id': 18160827,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ISR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '80.0',
#    'NumericValue': 79.98025,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:22.497+02:00'},
#   {'Id': 18160881,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ITA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.7',
#    'NumericValue': 79.68913,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:23.913+02:00'},
#   {'Id': 18160935,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JAM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.8',
#    'NumericValue': 72.77527,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:40:25.357+02:00'},
#   {'Id': 18160989,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JOR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.0',
#    'NumericValue': 72.0177,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:26.773+02:00'},
#   {'Id': 18161043,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JPN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.6',
#    'NumericValue': 79.59728,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:28.45+02:00'},
#   {'Id': 18161097,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KAZ',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.4',
#    'NumericValue': 63.35766,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:29.847+02:00'},
#   {'Id': 18161151,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KEN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.4',
#    'NumericValue': 62.37939,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:40:31.157+02:00'},
#   {'Id': 18161205,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KGZ',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.3',
#    'NumericValue': 65.34672,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:40:32.47+02:00'},
#   {'Id': 18161259,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KHM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.6',
#    'NumericValue': 65.55189,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:40:33.933+02:00'},
#   {'Id': 18161313,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KIR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
# ...
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.8',
#    'NumericValue': 76.76121,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:41:56.55+02:00'},
#   {'Id': 18164823,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SWE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.8',
#    'NumericValue': 79.84527,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:41:57.653+02:00'},
#   {'Id': 18164877,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SWZ',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.1',
#    'NumericValue': 51.12733,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:41:58.907+02:00'},
#   {'Id': 18164931,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SYC',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.3',
#    'NumericValue': 68.31893,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:00.013+02:00'},
#   {'Id': 18164985,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SYR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.8',
#    'NumericValue': 70.82381,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:01.17+02:00'},
#   {'Id': 18165039,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TCD',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.4',
#    'NumericValue': 51.36343,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:42:02.373+02:00'},
#   {'Id': 18165093,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TGO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.8',
#    'NumericValue': 57.82869,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:42:03.5+02:00'},
#   {'Id': 18165147,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'THA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.7',
#    'NumericValue': 70.74332,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Other HIV countries',
#    'Date': '2018-04-06T10:42:04.74+02:00'},
#   {'Id': 18165201,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TJK',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.1',
#    'NumericValue': 68.07426,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:06.03+02:00'},
#   {'Id': 18165255,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TKM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.3',
#    'NumericValue': 63.2622,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:07.147+02:00'},
#   {'Id': 18165309,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TLS',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.9',
#    'NumericValue': 65.9088,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:08.387+02:00'},
#   {'Id': 18165363,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TON',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.0',
#    'NumericValue': 69.98469,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:09.593+02:00'},
#   {'Id': 18165417,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TTO',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.6',
#    'NumericValue': 67.62517,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:10.87+02:00'},
#   {'Id': 18165471,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TUN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.0',
#    'NumericValue': 72.99088,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:12.103+02:00'},
#   {'Id': 18165525,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TUR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.7',
#    'NumericValue': 71.69945,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:13.43+02:00'},
#   {'Id': 18165579,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TZA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.6',
#    'NumericValue': 58.5601,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:42:14.703+02:00'},
#   {'Id': 18165633,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'UGA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.1',
#    'NumericValue': 57.08188,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:42:15.98+02:00'},
#   {'Id': 18165687,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'UKR',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.6',
#    'NumericValue': 65.62519,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:17.3+02:00'},
#   {'Id': 18165741,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'URY',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.4',
#    'NumericValue': 72.36556,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:18.607+02:00'},
#   {'Id': 18165795,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'USA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '76.5',
#    'NumericValue': 76.48037,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:19.907+02:00'},
#   {'Id': 18165849,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'UZB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '68.3',
#    'NumericValue': 68.31103,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:21.193+02:00'},
#   {'Id': 18165903,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'VCT',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.1',
#    'NumericValue': 70.10944,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:22.423+02:00'},
#   {'Id': 18165957,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'VEN',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.4',
#    'NumericValue': 69.39857,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:42:23.653+02:00'},
#   {'Id': 18166011,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'VNM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.7',
#    'NumericValue': 70.728,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:24.917+02:00'},
#   {'Id': 18166065,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'VUT',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '69.7',
#    'NumericValue': 69.65242,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:26.033+02:00'},
#   {'Id': 18166119,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'WSM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '70.7',
#    'NumericValue': 70.73186,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:27.37+02:00'},
#   {'Id': 18166173,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'YEM',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.2',
#    'NumericValue': 63.23826,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:42:28.68+02:00'},
#   {'Id': 18166227,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZAF',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.4',
#    'NumericValue': 56.36327,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:42:29.94+02:00'},
#   {'Id': 18166281,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZMB',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.7',
#    'NumericValue': 56.7287,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:42:31.283+02:00'},
#   {'Id': 18166335,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZWE',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.6',
#    'NumericValue': 53.55873,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: High HIV countries',
#    'Date': '2018-04-06T10:42:32.45+02:00'}]}

# %% [markdown]
# ## Using null filter

# %% [markdown]
# You can also filter the data returned by the web service by identifying whether an indicator displays facts that have or not dissagregation dimensions.
#
# Building on the example above, take the code **WHOSIS_000001**, `"Life expectancy at birth"` and retrieve the data for this indicator that is dis-aggregated or not

# %%
response = requests.get("https://ghoapi.azureedge.net/api/WHOSIS_000001?$filter=Dim1 ne null")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': [{'Id': 15578241,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.0',
#    'NumericValue': 42.99474,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.203+02:00'},
#   {'Id': 15578243,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.4',
#    'NumericValue': 48.38779,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.36+02:00'},
#   {'Id': 15578245,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '45.7',
#    'NumericValue': 45.70058,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.453+02:00'},
#   {'Id': 15578247,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '43.5',
#    'NumericValue': 43.48892,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.58+02:00'},
#   {'Id': 15578249,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.5',
#    'NumericValue': 49.4939,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.687+02:00'},
#   {'Id': 15578251,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.5',
#    'NumericValue': 46.4939,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.777+02:00'},
#   {'Id': 15578253,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '46.0',
#    'NumericValue': 46.02686,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.83+02:00'},
#   {'Id': 15578255,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.5',
#    'NumericValue': 51.45327,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.893+02:00'},
#   {'Id': 15578257,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '48.8',
#    'NumericValue': 48.76327,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:36.943+02:00'},
#   {'Id': 15578259,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '47.4',
#    'NumericValue': 47.43979,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.07+02:00'},
#   {'Id': 15578261,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '52.9',
#    'NumericValue': 52.90927,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.127+02:00'},
#   {'Id': 15578263,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '50.2',
#    'NumericValue': 50.20816,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.193+02:00'},
#   {'Id': 15578265,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '49.0',
#    'NumericValue': 49.0172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.253+02:00'},
#   {'Id': 15578267,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.64111,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.31+02:00'},
#   {'Id': 15578269,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.9',
#    'NumericValue': 51.87408,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.4+02:00'},
#   {'Id': 15578271,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '51.0',
#    'NumericValue': 51.02977,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.523+02:00'},
#   {'Id': 15578273,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.1',
#    'NumericValue': 57.07021,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.58+02:00'},
#   {'Id': 15578275,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.1',
#    'NumericValue': 54.10822,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.63+02:00'},
#   {'Id': 15578277,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '53.3',
#    'NumericValue': 53.29705,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.697+02:00'},
#   {'Id': 15578279,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.0',
#    'NumericValue': 59.96988,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.777+02:00'},
#   {'Id': 15578281,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.7',
#    'NumericValue': 56.70158,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.853+02:00'},
#   {'Id': 15578283,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.2',
#    'NumericValue': 55.24638,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.937+02:00'},
#   {'Id': 15578285,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.2',
#    'NumericValue': 62.19933,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:37.997+02:00'},
#   {'Id': 15578287,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.8',
#    'NumericValue': 58.7995,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.05+02:00'},
#   {'Id': 15578289,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.4',
#    'NumericValue': 56.40147,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.107+02:00'},
#   {'Id': 15578291,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.3',
#    'NumericValue': 63.26159,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.213+02:00'},
#   {'Id': 15578293,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.91484,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.307+02:00'},
#   {'Id': 15578295,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.1',
#    'NumericValue': 56.06949,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.367+02:00'},
#   {'Id': 15578297,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.7',
#    'NumericValue': 63.65812,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.447+02:00'},
#   {'Id': 15578299,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.94343,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.513+02:00'},
#   {'Id': 15578301,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04501,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.58+02:00'},
#   {'Id': 15578303,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.9',
#    'NumericValue': 64.89055,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.68+02:00'},
#   {'Id': 15578305,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6',
#    'NumericValue': 61.56371,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.763+02:00'},
#   {'Id': 15578307,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90235,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.82+02:00'},
#   {'Id': 15578309,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '65.7',
#    'NumericValue': 65.69534,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.883+02:00'},
#   {'Id': 15578311,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.4',
#    'NumericValue': 62.39735,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:38.973+02:00'},
#   {'Id': 15578313,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.7',
#    'NumericValue': 59.65667,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.04+02:00'},
#   {'Id': 15578315,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.3',
#    'NumericValue': 66.2644,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.13+02:00'},
#   {'Id': 15578317,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.1',
#    'NumericValue': 63.06204,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.203+02:00'},
#   {'Id': 15578319,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.4',
#    'NumericValue': 60.40749,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.273+02:00'},
#   {'Id': 15578321,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '66.7',
#    'NumericValue': 66.72172,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.343+02:00'},
#   {'Id': 15578323,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.7',
#    'NumericValue': 63.67279,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.453+02:00'},
#   {'Id': 15578325,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.1',
#    'NumericValue': 61.13641,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.823+02:00'},
#   {'Id': 15578327,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.1',
#    'NumericValue': 67.076,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.89+02:00'},
#   {'Id': 15578329,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.2',
#    'NumericValue': 64.22249,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:39.97+02:00'},
#   {'Id': 15578331,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.9',
#    'NumericValue': 61.87112,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.053+02:00'},
#   {'Id': 15578333,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '67.4',
#    'NumericValue': 67.39024,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.187+02:00'},
#   {'Id': 15578335,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'RWA',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.8',
#    'NumericValue': 64.75297,
#    'Low': None,
#    'High': None,
#    'Comments': None,
#    'Date': '2017-03-31T08:14:40.28+02:00'},
#   {'Id': 18156496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '54.6',
#    'NumericValue': 54.60243,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.39+02:00'},
#   {'Id': 18156497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.3',
#    'NumericValue': 55.29549,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.423+02:00'},
#   {'Id': 18156498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.45111,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.443+02:00'},
#   {'Id': 18156499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.9',
#    'NumericValue': 56.94814,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.47+02:00'},
#   {'Id': 18156500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.36723,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.497+02:00'},
#   {'Id': 18156501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.8',
#    'NumericValue': 57.81836,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.52+02:00'},
#   {'Id': 18156502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 58.04882,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.547+02:00'},
#   {'Id': 18156503,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.38523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.58+02:00'},
#   {'Id': 18156504,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.0',
#    'NumericValue': 59.0,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.61+02:00'},
#   {'Id': 18156505,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.5',
#    'NumericValue': 59.45721,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.63+02:00'},
#   {'Id': 18156506,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.9',
#    'NumericValue': 59.90372,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.65+02:00'},
#   {'Id': 18156507,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.45234,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.673+02:00'},
#   {'Id': 18156508,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.9',
#    'NumericValue': 60.94415,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.7+02:00'},
#   {'Id': 18156509,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.5',
#    'NumericValue': 61.49583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.727+02:00'},
#   {'Id': 18156510,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.7',
#    'NumericValue': 61.65874,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.75+02:00'},
#   {'Id': 18156511,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.8',
#    'NumericValue': 61.79883,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.777+02:00'},
#   {'Id': 18156512,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 61.04462,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.807+02:00'},
#   {'Id': 18156514,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.3',
#    'NumericValue': 57.29959,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.853+02:00'},
#   {'Id': 18156515,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.9',
#    'NumericValue': 57.85725,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.877+02:00'},
#   {'Id': 18156516,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.5',
#    'NumericValue': 58.49403,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.893+02:00'},
#   {'Id': 18156517,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.1',
#    'NumericValue': 59.06556,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.913+02:00'},
#   {'Id': 18156518,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.6',
#    'NumericValue': 59.57045,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.937+02:00'},
#   {'Id': 18156519,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.1',
#    'NumericValue': 60.08017,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.96+02:00'},
#   {'Id': 18156520,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.5',
#    'NumericValue': 60.5066,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:31.987+02:00'},
#   {'Id': 18156521,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.0',
#    'NumericValue': 60.97018,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.01+02:00'},
#   {'Id': 18156522,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '61.6',
#    'NumericValue': 61.56165,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.033+02:00'},
#   {'Id': 18156523,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.1',
#    'NumericValue': 62.06646,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.053+02:00'},
#   {'Id': 18156524,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '62.5',
#    'NumericValue': 62.54279,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.08+02:00'},
#   {'Id': 18156525,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.1',
#    'NumericValue': 63.07744,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.103+02:00'},
#   {'Id': 18156526,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '63.6',
#    'NumericValue': 63.55457,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.123+02:00'},
#   {'Id': 18156527,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.1',
#    'NumericValue': 64.07648,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.143+02:00'},
#   {'Id': 18156528,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.4',
#    'NumericValue': 64.37848,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.163+02:00'},
#   {'Id': 18156529,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.7',
#    'NumericValue': 64.67819,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.187+02:00'},
#   {'Id': 18156530,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '64.5',
#    'NumericValue': 64.49557,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.207+02:00'},
#   {'Id': 18156532,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '55.9',
#    'NumericValue': 55.89618,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.25+02:00'},
#   {'Id': 18156533,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '56.5',
#    'NumericValue': 56.52523,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.27+02:00'},
#   {'Id': 18156534,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '57.4',
#    'NumericValue': 57.43997,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.29+02:00'},
#   {'Id': 18156535,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.0',
#    'NumericValue': 57.971,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.31+02:00'},
#   {'Id': 18156536,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.4',
#    'NumericValue': 58.42978,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.333+02:00'},
#   {'Id': 18156537,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '58.9',
#    'NumericValue': 58.90924,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.353+02:00'},
#   {'Id': 18156538,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.2',
#    'NumericValue': 59.23066,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.37+02:00'},
#   {'Id': 18156539,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '59.6',
#    'NumericValue': 59.62808,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.39+02:00'},
#   {'Id': 18156540,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AFG',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'BTSX',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '60.2',
#    'NumericValue': 60.23545,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: World Population Prospects, 2017 revision (United Nations, Population Division)',
#    'Date': '2018-04-06T10:38:32.42+02:00'},
#   {'Id': 18156541,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
# ...
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.0',
#    'NumericValue': 72.02805,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.91+02:00'},
#   {'Id': 18157472,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.4',
#    'NumericValue': 72.38357,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.93+02:00'},
#   {'Id': 18157473,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '71.6',
#    'NumericValue': 71.61191,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.957+02:00'},
#   {'Id': 18157474,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.5',
#    'NumericValue': 72.52351,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:55.977+02:00'},
#   {'Id': 18157475,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '72.3',
#    'NumericValue': 72.33039,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56+02:00'},
#   {'Id': 18157476,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.0',
#    'NumericValue': 72.95933,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.02+02:00'},
#   {'Id': 18157477,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.3',
#    'NumericValue': 73.25368,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.04+02:00'},
#   {'Id': 18157478,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.5',
#    'NumericValue': 73.49396,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.06+02:00'},
#   {'Id': 18157479,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '73.9',
#    'NumericValue': 73.93802,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.08+02:00'},
#   {'Id': 18157480,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.0',
#    'NumericValue': 74.03307,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.103+02:00'},
#   {'Id': 18157481,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.11275,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.127+02:00'},
#   {'Id': 18157482,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.1',
#    'NumericValue': 74.13898,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.15+02:00'},
#   {'Id': 18157483,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.5',
#    'NumericValue': 74.52892,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.173+02:00'},
#   {'Id': 18157484,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'MLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '74.8',
#    'NumericValue': 74.75126,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.193+02:00'},
#   {'Id': 18157486,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2000,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.1',
#    'NumericValue': 77.09014,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.233+02:00'},
#   {'Id': 18157487,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2001,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.69583,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.257+02:00'},
#   {'Id': 18157488,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2002,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.8',
#    'NumericValue': 77.78509,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.277+02:00'},
#   {'Id': 18157489,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2003,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.6',
#    'NumericValue': 77.57087,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.303+02:00'},
#   {'Id': 18157490,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2004,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.5',
#    'NumericValue': 77.54809,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.323+02:00'},
#   {'Id': 18157491,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2005,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.3',
#    'NumericValue': 77.28371,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.347+02:00'},
#   {'Id': 18157492,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2006,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.9',
#    'NumericValue': 77.91827,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.367+02:00'},
#   {'Id': 18157493,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2007,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '77.7',
#    'NumericValue': 77.72093,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.39+02:00'},
#   {'Id': 18157494,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2008,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.5',
#    'NumericValue': 78.5369,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.437+02:00'},
#   {'Id': 18157495,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2009,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.4',
#    'NumericValue': 78.40302,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.473+02:00'},
#   {'Id': 18157496,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2010,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '78.6',
#    'NumericValue': 78.5621,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.5+02:00'},
#   {'Id': 18157497,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2011,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.1',
#    'NumericValue': 79.13873,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.52+02:00'},
#   {'Id': 18157498,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2012,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.2',
#    'NumericValue': 79.24512,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.55+02:00'},
#   {'Id': 18157499,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2013,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3',
#    'NumericValue': 79.29684,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.57+02:00'},
#   {'Id': 18157500,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2014,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.3',
#    'NumericValue': 79.32494,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.59+02:00'},
#   {'Id': 18157501,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2015,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.6',
#    'NumericValue': 79.57848,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.617+02:00'},
#   {'Id': 18157502,
#    'IndicatorCode': 'WHOSIS_000001',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'TimeDimType': 'YEAR',
#    'TimeDim': 2016,
#    'Dim1Type': 'SEX',
#    'Dim1': 'FMLE',
#    'Dim2Type': None,
#    'Dim2': None,
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '79.8',
#    'NumericValue': 79.75803,
#    'Low': None,
#    'High': None,
#    'Comments': 'WHO life table method: Vital registration',
#    'Date': '2018-04-06T10:38:56.64+02:00'},
#   ...]}

# %%
response = requests.get("https://ghoapi.azureedge.net/api/WHOSIS_000001?$filter=Dim1 eq null")
response.json()
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#WHOSIS_000001',
#  'value': []}
